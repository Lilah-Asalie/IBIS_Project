# %%
import numpy as np
from oneargopy.OneArgo import Argo
from argopy import DataFetcher as ArgoDataFetcher
import pandas as pd
import matplotlib.pyplot as plt
import cartopy.crs as ccrs
import matplotlib.pyplot as plt
import cartopy.feature as cfeature
import cmocean
import matplotlib.colors as mcolors
import matplotlib.dates as mdates
import matplotlib.cm as cm # new package for the colorbar
import matplotlib.patches as mpatches
from cartopy.mpl.ticker import LongitudeFormatter, LatitudeFormatter
from matplotlib.ticker import LogLocator, FormatStrFormatter
from matplotlib.colors import LogNorm
import gsw

# %%
argo = Argo('argo_config.json')
# Out:
# Starting initialize process...
# Your current download settings are:
# [DownloadSettings] ->
# Base Directory: .,
# Subdirectories: ['Index', 'Meta', 'Tech', 'Traj', 'Profiles'],
# Index Files: ['ar_index_global_traj.txt', 'ar_index_global_tech.txt', 'ar_index_global_meta.txt', 'ar_index_global_prof.txt', 'argo_synthetic-profile_index.txt'],
# Verbose Setting: True,
# Max Attempts: 5,
# Keep Index In Memory: True,
# Float Type: bgc
#
# Your current source settings are:
# [Source Settings] ->
# Hosts: ['https://data-argo.ifremer.fr/', 'https://usgodae.org/ftp/outgoing/argo/'],
# Available Variables: None,
# Data Assimilation Centers: None
#
# Checking for subdirectories...
# The Index directory already exists
# The Meta directory already exists
# The Tech directory already exists
# The Traj directory already exists
# The Profiles directory already exists
#
# Downloading index files...
# Updating ar_index_global_traj.txt...
# Downloading ar_index_global_traj.txt from https://data-argo.ifremer.fr/ar_index_global_traj.txt.gz...
# Unzipping ar_index_global_traj.txt.gz...
# Success!
# Updating ar_index_global_tech.txt...
# Downloading ar_index_global_tech.txt from https://data-argo.ifremer.fr/ar_index_global_tech.txt.gz...
# Unzipping ar_index_global_tech.txt.gz...
# Success!
# Updating ar_index_global_meta.txt...
# Downloading ar_index_global_meta.txt from https://data-argo.ifremer.fr/ar_index_global_meta.txt.gz...
# Unzipping ar_index_global_meta.txt.gz...
# Success!
# Updating ar_index_global_prof.txt...
# Downloading ar_index_global_prof.txt from https://data-argo.ifremer.fr/ar_index_global_prof.txt.gz...
# Unzipping ar_index_global_prof.txt.gz...
# Success!
# Updating argo_synthetic-profile_index.txt...
# Downloading argo_synthetic-profile_index.txt from https://data-argo.ifremer.fr/argo_synthetic-profile_index.txt.gz...
# Unzipping argo_synthetic-profile_index.txt.gz...
# Success!
#
# Transferring index files into dataframes...
# Filling in source settings information...
# Marking Parameters with their data mode...
# Filling in source settings information...
# Marking bgc floats in prof_index dataframe...
# Creating float_stats dataframe...
#
# 20342 floats with 3371398 profiles found.
# 2912 BGC floats with 395787 profiles found.
# Initialization is finished

# %%
pressure = argo.select_profiles(lon_lim=[150,180], lat_lim=[-68,-58], type = 'bgc', sensor = 'CHLA') # all bgc floats within region
# Out:
# Starting select_profiles...
# Validating parameters...
# Validating longitude and latitude limits...
# Validating start and end dates...
# Validating 'type' keyword argument...
# Preparing float data for filtering...
# Filtering through 20342 floats
# There are 3343134 profiles associated with these floats
#
# Sorting floats for those within the geographic range...
# Creating point list from profiles...
# Creating polygon...
# 79 floats fall within the geographic range
# 2602 profiles associated with those floats
# Applying outside=None constraints...
# 79 floats selected
# 2602 profiles selected according to time and space constraints
# Floats Selected: dict_keys([1901135, 1901153, 1901155, 1901157, 1902662, 2901936, 2903454, 3902129, 4903658, 5900345, 5901178, 5901645, 5901648, 5901698, 5901699, 5903242, 5903248, 5903260, 5903630, 5903717, 5903719, 5903720, 5903721, 5903722, 5903723, 5903939, 5904104, 5904105, 5904179, 5904481, 5904482, 5904483, 5904598, 5904599, 5904676, 5904677, 5904682, 5904688, 5905096, 5905097, 5905098, 5905099, 5905100, 5905101, 5905102, 5905103, 5905232, 5905372, 5905373, 5905374, 5905375, 5905376, 5905377, 5905379, 5905396, 5905555, 5905556, 5905557, 5905638, 5906207, 5906221, 5906442, 5906509, 5906581, 5906582, 5906583, 5906624, 6901004, 6902814, 6902885, 6902891, 6903190, 6903233, 6903768, 6903777, 6990587, 7902154, 7902155, 7902379])

# %% [markdown]
# ## Troubleshooting new data downloading
# problem floats: 3902129, 6902814
#
# Dataframe ran fine without the two floats above: they gave an "unsupported type for timedelta days component: MaskedConstant" error

# %%
df_2 = argo.load_float_data(pressure)
# Out:
# Validating passed floats...
# 1901135_Sprof.nc does not need to be updated yet.
# 1901153_Sprof.nc does not need to be updated yet.
# 1901155_Sprof.nc does not need to be updated yet.
# 1901157_Sprof.nc does not need to be updated yet.
# 1902662_Sprof.nc does not need to be updated yet.
# 2901936_Sprof.nc does not need to be updated yet.
# 2903454_Sprof.nc does not need to be updated yet.
# 3902129_Sprof.nc does not need to be updated yet.
# 4903658_Sprof.nc does not need to be updated yet.
# 5900345_Sprof.nc does not need to be updated yet.
# 5901178_Sprof.nc does not need to be updated yet.
# 5901645_Sprof.nc does not need to be updated yet.
# 5901648_Sprof.nc does not need to be updated yet.
# 5901698_Sprof.nc does not need to be updated yet.
# 5901699_Sprof.nc does not need to be updated yet.
# 5903242_Sprof.nc does not need to be updated yet.
# 5903248_Sprof.nc does not need to be updated yet.
# 5903260_Sprof.nc does not need to be updated yet.
# 5903630_Sprof.nc does not need to be updated yet.
# 5903717_Sprof.nc does not need to be updated yet.
# 5903719_Sprof.nc does not need to be updated yet.
# 5903720_Sprof.nc does not need to be updated yet.
# 5903721_Sprof.nc does not need to be updated yet.
# 5903722_Sprof.nc does not need to be updated yet.
# 5903723_Sprof.nc does not need to be updated yet.
# 5903939_Sprof.nc does not need to be updated yet.
# 5904104_Sprof.nc does not need to be updated yet.
# 5904105_Sprof.nc does not need to be updated yet.
# 5904179_Sprof.nc does not need to be updated yet.
# 5904481_Sprof.nc does not need to be updated yet.
# 5904482_Sprof.nc does not need to be updated yet.
# 5904483_Sprof.nc does not need to be updated yet.
# 5904598_Sprof.nc does not need to be updated yet.
# 5904599_Sprof.nc does not need to be updated yet.
# 5904676_Sprof.nc does not need to be updated yet.
# 5904677_Sprof.nc does not need to be updated yet.
# 5904682_Sprof.nc does not need to be updated yet.
# 5904688_Sprof.nc does not need to be updated yet.
# 5905096_Sprof.nc does not need to be updated yet.
# 5905097_Sprof.nc does not need to be updated yet.
# 5905098_Sprof.nc does not need to be updated yet.
# 5905099_Sprof.nc does not need to be updated yet.
# 5905100_Sprof.nc does not need to be updated yet.
# 5905101_Sprof.nc does not need to be updated yet.
# 5905102_Sprof.nc does not need to be updated yet.
# 5905103_Sprof.nc does not need to be updated yet.
# 5905232_Sprof.nc does not need to be updated yet.
# 5905372_Sprof.nc does not need to be updated yet.
# 5905373_Sprof.nc does not need to be updated yet.
# 5905374_Sprof.nc does not need to be updated yet.
# 5905375_Sprof.nc does not need to be updated yet.
# 5905376_Sprof.nc does not need to be updated yet.
# 5905377_Sprof.nc does not need to be updated yet.
# 5905379_Sprof.nc does not need to be updated yet.
# 5905396_Sprof.nc does not need to be updated yet.
# 5905555_Sprof.nc does not need to be updated yet.
# 5905556_Sprof.nc does not need to be updated yet.
# 5905557_Sprof.nc does not need to be updated yet.
# 5905638_Sprof.nc does not need to be updated yet.
# 5906207_Sprof.nc does not need to be updated yet.
# 5906221_Sprof.nc does not need to be updated yet.
# 5906442_Sprof.nc does not need to be updated yet.
# 5906509_Sprof.nc does not need to be updated yet.
# 5906581_Sprof.nc does not need to be updated yet.
# 5906582_Sprof.nc does not need to be updated yet.
# 5906583_Sprof.nc does not need to be updated yet.
# 5906624_Sprof.nc does not need to be updated yet.
# 6901004_Sprof.nc does not need to be updated yet.
# 6902814_Sprof.nc does not need to be updated yet.
# 6902885_Sprof.nc does not need to be updated yet.
# 6902891_Sprof.nc does not need to be updated yet.
# 6903190_Sprof.nc does not need to be updated yet.
# 6903233_Sprof.nc does not need to be updated yet.
# 6903768_Sprof.nc does not need to be updated yet.
# 6903777_Sprof.nc does not need to be updated yet.
# 6990587_Sprof.nc does not need to be updated yet.
# 7902154_Sprof.nc does not need to be updated yet.
# 7902155_Sprof.nc does not need to be updated yet.
# 7902379_Sprof.nc does not need to be updated yet.
# Loading float data...
# Loading Float data from float 1901135 with 1 profiles...
# Loading Float data from float 1901153 with 5 profiles...
# Loading Float data from float 1901155 with 6 profiles...
# Loading Float data from float 1901157 with 45 profiles...
# Loading Float data from float 1902662 with 23 profiles...
# Loading Float data from float 2901936 with 98 profiles...
# Loading Float data from float 2903454 with 40 profiles...
# Loading Float data from float 3902129 with 57 profiles...
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[83], line 1
# ----> 1 df_2 = argo.load_float_data(pressure)
#
# File /opt/anaconda3/envs/IBIS_Project/lib/python3.13/site-packages/oneargopy/OneArgo.py:329, in Argo.load_float_data(self, floats, variables)
#     327     self.__download_file(file_name)
#     328 # Read from nc files into dataframe
# --> 329 float_data_frame = self.__fill_float_data_dataframe(files)
#     330 return float_data_frame
#
# File /opt/anaconda3/envs/IBIS_Project/lib/python3.13/site-packages/oneargopy/OneArgo.py:1374, in Argo.__fill_float_data_dataframe(self, files)
#    1371 for column in static_columns:
#    1372     # Customize nc_variable if we have a special case where values need to be calculated
#    1373     if column in special_case_static_columns:
# -> 1374         nc_variable = self.__calculate_nc_variable_values(column, nc_file,
#    1375                                                           static_length,
#    1376                                                           profiles_to_pull)
#    1377     else:
#    1378         nc_variable = nc_file.variables[column][profiles_to_pull]
#
# File /opt/anaconda3/envs/IBIS_Project/lib/python3.13/site-packages/oneargopy/OneArgo.py:1447, in Argo.__calculate_nc_variable_values(self, column, nc_file, number_of_profiles, profiles_to_pull)
#    1445     for date in nc_variable:
#    1446         reference_date = datetime(1950, 1, 1)
# -> 1447         utc_date = reference_date + timedelta(days=date)
#    1448         new_nc_variable.append(utc_date)
#    1449 # Returning list of calculated lists to be added to dataframe
#
# TypeError: unsupported type for timedelta days component: MaskedConstant

# %%
# float ids from argo.select_profiles function for extended AAR region
float_ids = [1901135, 1901155, 1901157, 1902662, 2901936, 2903454, 4903658, 5900345, 5901178, 5901645, 5901648, 5901698, 5901699, 5903242, 5903248, 5903260, 5903630, 5903717, 5903719, 5903720, 5903721, 5903722, 5903723, 5903939, 5904104, 5904105, 5904179, 5904481, 5904482, 5904483, 5904598, 5904599, 5904676, 5904677, 5904682, 5904688, 5905096, 5905097, 5905098, 5905099, 5905100, 5905101, 5905102, 5905103, 5905232, 5905372, 5905373, 5905374, 5905375, 5905376, 5905377, 5905379, 5905396, 5905555, 5905556, 5905557, 5905638, 5906207, 5906221, 5906442, 5906509, 5906581, 5906582, 5906583, 5906624, 6901004, 6902885, 6902891, 6903190, 6903233, 6903768, 6903777, 6990587, 7902154, 7902155, 7902379]

# %%
float_ids = [1901135, 1901153, 1901155, 1901157, 1902662, 2901936, 2903454, 3902129, 4903658, 5900345, 5901178, 5901645, 5901648, 5901698, 5901699, 5903242, 5903248, 5903260, 5903630, 5903717, 5903719, 5903720, 5903721, 5903722, 5903723, 5903939, 5904104, 5904105, 5904179, 5904481, 5904482, 5904483, 5904598, 5904599, 5904676, 5904677, 5904682, 5904688, 5905096, 5905097, 5905098, 5905099, 5905100, 5905101, 5905102, 5905103, 5905232, 5905372, 5905373, 5905374, 5905375, 5905376, 5905377, 5905379, 5905396, 5905555, 5905556, 5905557, 5905638, 5906207, 5906221, 5906442, 5906509, 5906581, 5906582, 5906583, 5906624, 6901004, 6902814, 6902885, 6902891, 6903190, 6903233, 6903768, 6903777, 6990587, 7902154, 7902155, 7902379]

# %%
df = argo.load_float_data(float_ids)
# Out:
# Validating passed floats...
# 1901135_prof.nc needs to be downloaded.
# Downloading 1901135_prof.nc from https://data-argo.ifremer.fr/dac/csiro/1901135/1901135_prof.nc...
# Success!
# 1901153_prof.nc needs to be downloaded.
# Downloading 1901153_prof.nc from https://data-argo.ifremer.fr/dac/csiro/1901153/1901153_prof.nc...
# Success!
# 1901155_prof.nc needs to be downloaded.
# Downloading 1901155_prof.nc from https://data-argo.ifremer.fr/dac/csiro/1901155/1901155_prof.nc...
# Success!
# 1901157_prof.nc needs to be downloaded.
# Downloading 1901157_prof.nc from https://data-argo.ifremer.fr/dac/csiro/1901157/1901157_prof.nc...
# Success!
# 1902662_prof.nc needs to be downloaded.
# Downloading 1902662_prof.nc from https://data-argo.ifremer.fr/dac/coriolis/1902662/1902662_prof.nc...
# Success!
# 2901936_prof.nc needs to be downloaded.
# Downloading 2901936_prof.nc from https://data-argo.ifremer.fr/dac/bodc/2901936/2901936_prof.nc...
# Success!
# 2903454_prof.nc needs to be downloaded.
# Downloading 2903454_prof.nc from https://data-argo.ifremer.fr/dac/aoml/2903454/2903454_prof.nc...
# Success!
# 3902129_prof.nc needs to be downloaded.
# Downloading 3902129_prof.nc from https://data-argo.ifremer.fr/dac/coriolis/3902129/3902129_prof.nc...
# Success!
# 4903658_prof.nc needs to be downloaded.
# Downloading 4903658_prof.nc from https://data-argo.ifremer.fr/dac/coriolis/4903658/4903658_prof.nc...
# Success!
# 5900345_prof.nc needs to be downloaded.
# Downloading 5900345_prof.nc from https://data-argo.ifremer.fr/dac/csiro/5900345/5900345_prof.nc...
# Success!
# 5901178_prof.nc needs to be downloaded.
# Downloading 5901178_prof.nc from https://data-argo.ifremer.fr/dac/csiro/5901178/5901178_prof.nc...
# Success!
# 5901645_prof.nc needs to be downloaded.
# Downloading 5901645_prof.nc from https://data-argo.ifremer.fr/dac/csiro/5901645/5901645_prof.nc...
# Success!
# 5901648_prof.nc needs to be downloaded.
# Downloading 5901648_prof.nc from https://data-argo.ifremer.fr/dac/csiro/5901648/5901648_prof.nc...
# Success!
# 5901698_prof.nc needs to be downloaded.
# Downloading 5901698_prof.nc from https://data-argo.ifremer.fr/dac/csiro/5901698/5901698_prof.nc...
# Success!
# 5901699_prof.nc needs to be downloaded.
# Downloading 5901699_prof.nc from https://data-argo.ifremer.fr/dac/csiro/5901699/5901699_prof.nc...
# Success!
# 5903242_prof.nc needs to be downloaded.
# Downloading 5903242_prof.nc from https://data-argo.ifremer.fr/dac/csiro/5903242/5903242_prof.nc...
# Success!
# 5903248_prof.nc needs to be downloaded.
# Downloading 5903248_prof.nc from https://data-argo.ifremer.fr/dac/csiro/5903248/5903248_prof.nc...
# Success!
# 5903260_prof.nc needs to be downloaded.
# Downloading 5903260_prof.nc from https://data-argo.ifremer.fr/dac/csiro/5903260/5903260_prof.nc...
# Success!
# 5903630_prof.nc needs to be downloaded.
# Downloading 5903630_prof.nc from https://data-argo.ifremer.fr/dac/csiro/5903630/5903630_prof.nc...
# Success!
# 5903717_prof.nc needs to be downloaded.
# Downloading 5903717_prof.nc from https://data-argo.ifremer.fr/dac/aoml/5903717/5903717_prof.nc...
# Success!
# 5903719_prof.nc needs to be downloaded.
# Downloading 5903719_prof.nc from https://data-argo.ifremer.fr/dac/aoml/5903719/5903719_prof.nc...
# Success!
# 5903720_prof.nc needs to be downloaded.
# Downloading 5903720_prof.nc from https://data-argo.ifremer.fr/dac/aoml/5903720/5903720_prof.nc...
# Success!
# 5903721_prof.nc needs to be downloaded.
# Downloading 5903721_prof.nc from https://data-argo.ifremer.fr/dac/aoml/5903721/5903721_prof.nc...
# Success!
# 5903722_prof.nc needs to be downloaded.
# Downloading 5903722_prof.nc from https://data-argo.ifremer.fr/dac/aoml/5903722/5903722_prof.nc...
# Success!
# 5903723_prof.nc needs to be downloaded.
# Downloading 5903723_prof.nc from https://data-argo.ifremer.fr/dac/aoml/5903723/5903723_prof.nc...
# Success!
# 5903939_prof.nc needs to be downloaded.
# Downloading 5903939_prof.nc from https://data-argo.ifremer.fr/dac/csiro/5903939/5903939_prof.nc...
# Success!
# 5904104_prof.nc needs to be downloaded.
# Downloading 5904104_prof.nc from https://data-argo.ifremer.fr/dac/aoml/5904104/5904104_prof.nc...
# Success!
# 5904105_prof.nc needs to be downloaded.
# Downloading 5904105_prof.nc from https://data-argo.ifremer.fr/dac/aoml/5904105/5904105_prof.nc...
# Success!
# 5904179_prof.nc needs to be downloaded.
# Downloading 5904179_prof.nc from https://data-argo.ifremer.fr/dac/aoml/5904179/5904179_prof.nc...
# Success!
# 5904481_prof.nc needs to be downloaded.
# Downloading 5904481_prof.nc from https://data-argo.ifremer.fr/dac/aoml/5904481/5904481_prof.nc...
# Success!
# 5904482_prof.nc needs to be downloaded.
# Downloading 5904482_prof.nc from https://data-argo.ifremer.fr/dac/aoml/5904482/5904482_prof.nc...
# Success!
# 5904483_prof.nc needs to be downloaded.
# Downloading 5904483_prof.nc from https://data-argo.ifremer.fr/dac/aoml/5904483/5904483_prof.nc...
# Success!
# 5904598_prof.nc needs to be downloaded.
# Downloading 5904598_prof.nc from https://data-argo.ifremer.fr/dac/aoml/5904598/5904598_prof.nc...
# Success!
# 5904599_prof.nc needs to be downloaded.
# Downloading 5904599_prof.nc from https://data-argo.ifremer.fr/dac/aoml/5904599/5904599_prof.nc...
# Success!
# 5904676_prof.nc needs to be downloaded.
# Downloading 5904676_prof.nc from https://data-argo.ifremer.fr/dac/aoml/5904676/5904676_prof.nc...
# Success!
# 5904677_prof.nc needs to be downloaded.
# Downloading 5904677_prof.nc from https://data-argo.ifremer.fr/dac/aoml/5904677/5904677_prof.nc...
# Success!
# 5904682_prof.nc needs to be downloaded.
# Downloading 5904682_prof.nc from https://data-argo.ifremer.fr/dac/aoml/5904682/5904682_prof.nc...
# Success!
# 5904688_prof.nc needs to be downloaded.
# Downloading 5904688_prof.nc from https://data-argo.ifremer.fr/dac/aoml/5904688/5904688_prof.nc...
# Success!
# 5905096_prof.nc needs to be downloaded.
# Downloading 5905096_prof.nc from https://data-argo.ifremer.fr/dac/aoml/5905096/5905096_prof.nc...
# Success!
# 5905097_prof.nc needs to be downloaded.
# Downloading 5905097_prof.nc from https://data-argo.ifremer.fr/dac/aoml/5905097/5905097_prof.nc...
# Success!
# 5905098_prof.nc needs to be downloaded.
# Downloading 5905098_prof.nc from https://data-argo.ifremer.fr/dac/aoml/5905098/5905098_prof.nc...
# Success!
# 5905099_prof.nc needs to be downloaded.
# Downloading 5905099_prof.nc from https://data-argo.ifremer.fr/dac/aoml/5905099/5905099_prof.nc...
# Success!
# 5905100_prof.nc needs to be downloaded.
# Downloading 5905100_prof.nc from https://data-argo.ifremer.fr/dac/aoml/5905100/5905100_prof.nc...
# Success!
# 5905101_prof.nc needs to be downloaded.
# Downloading 5905101_prof.nc from https://data-argo.ifremer.fr/dac/aoml/5905101/5905101_prof.nc...
# Success!
# 5905102_prof.nc needs to be downloaded.
# Downloading 5905102_prof.nc from https://data-argo.ifremer.fr/dac/aoml/5905102/5905102_prof.nc...
# Success!
# 5905103_prof.nc needs to be downloaded.
# Downloading 5905103_prof.nc from https://data-argo.ifremer.fr/dac/aoml/5905103/5905103_prof.nc...
# Success!
# 5905232_prof.nc needs to be downloaded.
# Downloading 5905232_prof.nc from https://data-argo.ifremer.fr/dac/jma/5905232/5905232_prof.nc...
# Success!
# 5905372_prof.nc needs to be downloaded.
# Downloading 5905372_prof.nc from https://data-argo.ifremer.fr/dac/aoml/5905372/5905372_prof.nc...
# Success!
# 5905373_prof.nc needs to be downloaded.
# Downloading 5905373_prof.nc from https://data-argo.ifremer.fr/dac/aoml/5905373/5905373_prof.nc...
# Success!
# 5905374_prof.nc needs to be downloaded.
# Downloading 5905374_prof.nc from https://data-argo.ifremer.fr/dac/aoml/5905374/5905374_prof.nc...
# Success!
# 5905375_prof.nc needs to be downloaded.
# Downloading 5905375_prof.nc from https://data-argo.ifremer.fr/dac/aoml/5905375/5905375_prof.nc...
# Success!
# 5905376_prof.nc needs to be downloaded.
# Downloading 5905376_prof.nc from https://data-argo.ifremer.fr/dac/aoml/5905376/5905376_prof.nc...
# Success!
# 5905377_prof.nc needs to be downloaded.
# Downloading 5905377_prof.nc from https://data-argo.ifremer.fr/dac/aoml/5905377/5905377_prof.nc...
# Success!
# 5905379_prof.nc needs to be downloaded.
# Downloading 5905379_prof.nc from https://data-argo.ifremer.fr/dac/aoml/5905379/5905379_prof.nc...
# Success!
# 5905396_prof.nc needs to be downloaded.
# Downloading 5905396_prof.nc from https://data-argo.ifremer.fr/dac/csiro/5905396/5905396_prof.nc...
# Success!
# 5905555_prof.nc needs to be downloaded.
# Downloading 5905555_prof.nc from https://data-argo.ifremer.fr/dac/csiro/5905555/5905555_prof.nc...
# Success!
# 5905556_prof.nc needs to be downloaded.
# Downloading 5905556_prof.nc from https://data-argo.ifremer.fr/dac/csiro/5905556/5905556_prof.nc...
# Success!
# 5905557_prof.nc needs to be downloaded.
# Downloading 5905557_prof.nc from https://data-argo.ifremer.fr/dac/csiro/5905557/5905557_prof.nc...
# Success!
# 5905638_prof.nc needs to be downloaded.
# Downloading 5905638_prof.nc from https://data-argo.ifremer.fr/dac/aoml/5905638/5905638_prof.nc...
# Success!
# 5906207_prof.nc needs to be downloaded.
# Downloading 5906207_prof.nc from https://data-argo.ifremer.fr/dac/aoml/5906207/5906207_prof.nc...
# Success!
# 5906221_prof.nc needs to be downloaded.
# Downloading 5906221_prof.nc from https://data-argo.ifremer.fr/dac/aoml/5906221/5906221_prof.nc...
# Success!
# 5906442_prof.nc needs to be downloaded.
# Downloading 5906442_prof.nc from https://data-argo.ifremer.fr/dac/aoml/5906442/5906442_prof.nc...
# Success!
# 5906509_prof.nc needs to be downloaded.
# Downloading 5906509_prof.nc from https://data-argo.ifremer.fr/dac/aoml/5906509/5906509_prof.nc...
# Success!
# 5906581_prof.nc needs to be downloaded.
# Downloading 5906581_prof.nc from https://data-argo.ifremer.fr/dac/aoml/5906581/5906581_prof.nc...
# Success!
# 5906582_prof.nc needs to be downloaded.
# Downloading 5906582_prof.nc from https://data-argo.ifremer.fr/dac/aoml/5906582/5906582_prof.nc...
# Success!
# 5906583_prof.nc needs to be downloaded.
# Downloading 5906583_prof.nc from https://data-argo.ifremer.fr/dac/aoml/5906583/5906583_prof.nc...
# Success!
# 5906624_prof.nc needs to be downloaded.
# Downloading 5906624_prof.nc from https://data-argo.ifremer.fr/dac/csiro/5906624/5906624_prof.nc...
# Success!
# 6901004_prof.nc needs to be downloaded.
# Downloading 6901004_prof.nc from https://data-argo.ifremer.fr/dac/coriolis/6901004/6901004_prof.nc...
# Success!
# 6902814_prof.nc needs to be downloaded.
# Downloading 6902814_prof.nc from https://data-argo.ifremer.fr/dac/coriolis/6902814/6902814_prof.nc...
# Success!
# 6902885_prof.nc needs to be downloaded.
# Downloading 6902885_prof.nc from https://data-argo.ifremer.fr/dac/coriolis/6902885/6902885_prof.nc...
# Success!
# 6902891_prof.nc needs to be downloaded.
# Downloading 6902891_prof.nc from https://data-argo.ifremer.fr/dac/coriolis/6902891/6902891_prof.nc...
# Success!
# 6903190_prof.nc needs to be downloaded.
# Downloading 6903190_prof.nc from https://data-argo.ifremer.fr/dac/coriolis/6903190/6903190_prof.nc...
# Success!
# 6903233_prof.nc needs to be downloaded.
# Downloading 6903233_prof.nc from https://data-argo.ifremer.fr/dac/coriolis/6903233/6903233_prof.nc...
# Success!
# 6903768_prof.nc needs to be downloaded.
# Downloading 6903768_prof.nc from https://data-argo.ifremer.fr/dac/coriolis/6903768/6903768_prof.nc...
# Success!
# 6903777_prof.nc needs to be downloaded.
# Downloading 6903777_prof.nc from https://data-argo.ifremer.fr/dac/coriolis/6903777/6903777_prof.nc...
# Success!
# 6990587_prof.nc needs to be downloaded.
# Downloading 6990587_prof.nc from https://data-argo.ifremer.fr/dac/aoml/6990587/6990587_prof.nc...
# Success!
# 7902154_prof.nc needs to be downloaded.
# Downloading 7902154_prof.nc from https://data-argo.ifremer.fr/dac/aoml/7902154/7902154_prof.nc...
# Success!
# 7902155_prof.nc needs to be downloaded.
# Downloading 7902155_prof.nc from https://data-argo.ifremer.fr/dac/aoml/7902155/7902155_prof.nc...
# Success!
# 7902379_prof.nc needs to be downloaded.
# Downloading 7902379_prof.nc from https://data-argo.ifremer.fr/dac/aoml/7902379/7902379_prof.nc...
# Success!
# Loading float data...
# Loading Float data from float 1901135 with 173 profiles...
# Loading Float data from float 1901153 with 309 profiles...
# Loading Float data from float 1901155 with 355 profiles...
# Loading Float data from float 1901157 with 322 profiles...
# Loading Float data from float 1902662 with 91 profiles...
# Loading Float data from float 2901936 with 172 profiles...
# Loading Float data from float 2903454 with 46 profiles...
# Loading Float data from float 3902129 with 61 profiles...
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 df = argo.load_float_data(float_ids)
#
# File /opt/anaconda3/envs/IBIS_Project/lib/python3.13/site-packages/oneargopy/OneArgo.py:329, in Argo.load_float_data(self, floats, variables)
#     327     self.__download_file(file_name)
#     328 # Read from nc files into dataframe
# --> 329 float_data_frame = self.__fill_float_data_dataframe(files)
#     330 return float_data_frame
#
# File /opt/anaconda3/envs/IBIS_Project/lib/python3.13/site-packages/oneargopy/OneArgo.py:1374, in Argo.__fill_float_data_dataframe(self, files)
#    1371 for column in static_columns:
#    1372     # Customize nc_variable if we have a special case where values need to be calculated
#    1373     if column in special_case_static_columns:
# -> 1374         nc_variable = self.__calculate_nc_variable_values(column, nc_file,
#    1375                                                           static_length,
#    1376                                                           profiles_to_pull)
#    1377     else:
#    1378         nc_variable = nc_file.variables[column][profiles_to_pull]
#
# File /opt/anaconda3/envs/IBIS_Project/lib/python3.13/site-packages/oneargopy/OneArgo.py:1447, in Argo.__calculate_nc_variable_values(self, column, nc_file, number_of_profiles, profiles_to_pull)
#    1445     for date in nc_variable:
#    1446         reference_date = datetime(1950, 1, 1)
# -> 1447         utc_date = reference_date + timedelta(days=date)
#    1448         new_nc_variable.append(utc_date)
#    1449 # Returning list of calculated lists to be added to dataframe
#
# TypeError: unsupported type for timedelta days component: MaskedConstant

# %%
df.to_csv('/Users/lilah/Documents/IBIS_Project/Data_Summer/new_bgc_profiles_BR_extended_area_all_time.csv', index = 'False')

# %%
type(df)
# Out:
# pandas.DataFrame

# %%
type(pressure)
# Out:
# dict

# %%
type(float_ids)
# Out:
# list
