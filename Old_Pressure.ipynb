# %%
pip install numpy==1.26.4 # for stevie's local machine, oneargo doesn't work with the latest version of numpy, use this version instead
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.8/15.8 MB 68.6 MB/s  0:00:00 eta 0:00:01
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Created wheel for numpy: filename=numpy-1.26.4-cp313-cp313-macosx_14_0_arm64.whl size=4680074 sha256=d0571813d213e66a9753fbac9b6228823866f6e7d4cf0790d2a40d54bfa5bbd7
#   Stored in directory: /Users/lilah/Library/Caches/pip/wheels/8b/2d/9f/b6b46373f328e2ef50388915d351ccacbedac929459b5459bf
# Successfully built numpy
# ...
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.3.5
#     Uninstalling numpy-2.3.5:
#       Successfully uninstalled numpy-2.3.5
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
from oneargopy.OneArgo import Argo
from argopy import DataFetcher as ArgoDataFetcher
import pandas as pd
import matplotlib.pyplot as plt
import cartopy.crs as ccrs
import matplotlib.pyplot as plt
import cartopy.feature as cfeature
import cmocean
import matplotlib.colors as mcolors
import matplotlib.dates as mdates
import matplotlib.cm as cm # new package for the colorbar
import matplotlib.patches as mpatches
from cartopy.mpl.ticker import LongitudeFormatter, LatitudeFormatter
from matplotlib.ticker import LogLocator, FormatStrFormatter
from matplotlib.colors import LogNorm
import gsw

# %% [markdown]
# ### Downloading float data

# %%
argo = Argo('argo_config.json')
# Out:
# Starting initialize process...
# Your current download settings are:
# [DownloadSettings] ->
# Base Directory: .,
# Subdirectories: ['Index', 'Meta', 'Tech', 'Traj', 'Profiles'],
# Index Files: ['ar_index_global_traj.txt', 'ar_index_global_tech.txt', 'ar_index_global_meta.txt', 'ar_index_global_prof.txt', 'argo_synthetic-profile_index.txt'],
# Verbose Setting: True,
# Max Attempts: 5,
# Keep Index In Memory: True,
# Float Type: bgc
#
# Your current source settings are:
# [Source Settings] ->
# Hosts: ['https://data-argo.ifremer.fr/', 'https://usgodae.org/ftp/outgoing/argo/'],
# Available Variables: None,
# Data Assimilation Centers: None
#
# Checking for subdirectories...
# The Index directory already exists
# The Meta directory already exists
# The Tech directory already exists
# The Traj directory already exists
# The Profiles directory already exists
#
# ...
# ar_index_global_traj.txt does not need to be updated yet.
# ar_index_global_tech.txt does not need to be updated yet.
# ...

# %%
# pressure = argo.select_profiles(lon_lim=[150,180], lat_lim=[-68,-58], start_date='2022-01-01', end_date='2022-12-31')
# pressure = argo.select_profiles(lon_lim=[150,180], lat_lim=[-68,-58], start_date='2014-06-01', end_date='2015-06-30') #captures 2014-2015 productive season
pressure = argo.select_profiles(lon_lim=[150,180], lat_lim=[-68,-58], type = 'bgc', sensor = 'CHLA') # all bgc floats within region
# Out:
# Starting select_profiles...
# Validating parameters...
# Validating longitude and latitude limits...
# Validating start and end dates...
# Validating 'type' keyword argument...
# Preparing float data for filtering...
# Filtering through 20159 floats
# There are 3307467 profiles associated with these floats
#
# Sorting floats for those within the geographic range...
# Creating point list from profiles...
# Creating polygon...
# 78 floats fall within the geographic range
# 2566 profiles associated with those floats
# Applying outside=None constraints...
# 78 floats selected
# 2566 profiles selected according to time and space constraints
# ...

# %%
argo.trajectories(pressure)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 argo.trajectories(pressure)
#
# NameError: name 'argo' is not defined

# %%
pdf = argo.load_float_data(pressure, variables=['DOXY','TEMP','PSAL','CHLA', 'BBP700','NITRATE','PH_IN_SITU_TOTAL'])
# Out:
# Validating passed floats...
# Validating passed 'variables'...
# 1901135_Sprof.nc does not need to be updated yet.
# 1901153_Sprof.nc does not need to be updated yet.
# 1901155_Sprof.nc does not need to be updated yet.
# 1901157_Sprof.nc does not need to be updated yet.
# 1902662_Sprof.nc does not need to be updated yet.
# Updating 2901936_Sprof.nc...
# ...
# Success!
# 2903454_Sprof.nc does not need to be updated yet.
# 3902129_Sprof.nc does not need to be updated yet.
# 4903658_Sprof.nc does not need to be updated yet.
# 5900345_Sprof.nc does not need to be updated yet.
# 5901178_Sprof.nc does not need to be updated yet.
# 5901645_Sprof.nc does not need to be updated yet.
# 5901648_Sprof.nc does not need to be updated yet.
# 5901698_Sprof.nc does not need to be updated yet.
# 5901699_Sprof.nc does not need to be updated yet.
# 5903242_Sprof.nc does not need to be updated yet.
# 5903248_Sprof.nc does not need to be updated yet.
# 5903260_Sprof.nc does not need to be updated yet.
# ...

# %%
pdf.to_csv('/Users/lilah/Documents/IBIS_Project/Data/bgc_profiles_BR_extended_area_all_time.csv', index = 'False')

# %% [markdown]
# ### Analyzing and plotting float data

# %%
pdf = pd.read_csv('/Users/lilah/Documents/IBIS_Project/Data/AAR_BGC_extended_region_alltime.csv')
# pdf = pd.read_csv('/Users/steviewalker/Documents/IBIS_Project/Data/AAR_BGC_extended_region_alltime.csv') #for stevie
# Out:
# /var/folders/sr/nn_fjjln6s33md98tyfc3rd40000gn/T/ipykernel_26791/518615070.py:1: DtypeWarning: Columns (6,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   pdf = pd.read_csv('/Users/lilah/Documents/IBIS_Project/Data/AAR_BGC_extended_region_alltime.csv')

# %%
#convert to datetime
pdf['DATE'] = pd.to_datetime(pdf['DATE'],format = 'mixed')
#add year and month columns
pdf["year"] = pdf["DATE"].dt.year
pdf["month"] = pdf["DATE"].dt.month

# Define a season label: if month >=10 then season = year-year+1, else if month <=3 then season = (year-1)-year
def assign_season(row):
    m = row["month"]
    y = row["year"]
    if m >= 8:         # Aug, Sept, Oct, Nov, Dec
        return f"{y}-{y+1}"
    elif m <= 4:        # Jan, Feb, Mar
        return f"{y-1}-{y}"
    else:
        return f"{y}"   # outside the austral productive season (Apr-Sep)

#subset data with good QC only
qc_flags = [1,2,8]
pdf_clean = pdf[pdf['CHLA_ADJUSTED_QC'].isin(qc_flags) & pdf['BBP700_ADJUSTED_QC'].isin(qc_flags) & pdf['DOXY_ADJUSTED_QC'].isin(qc_flags) & pdf['PSAL_ADJUSTED_QC'].isin(qc_flags)]

pdf_clean["season"] = pdf_clean.apply(assign_season, axis=1)
# Out:
# /var/folders/sr/nn_fjjln6s33md98tyfc3rd40000gn/T/ipykernel_26791/775759699.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pdf_clean["season"] = pdf_clean.apply(assign_season, axis=1)

# %%
pdf_clean['year']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 pdf_clean['year']
#
# NameError: name 'pdf_clean' is not defined

# %%
 # writing function
def subset_yr(df, yr1,yr2):
    
    subset = df[df['year'].isin([yr1,yr2])]
    # add subset by the productive months
    subset = subset[subset['month'].isin([1,2,3,4,8,9, 10,11,12])]
    
    return subset

pdf_yr = subset_yr(pdf_clean,2014,2015)
pdf_yr
# Out:
#         Unnamed: 0    WMOID  CYCLE_NUMBER DIRECTION  \
# 362247      362247  5904104            60         A
# 362250      362250  5904104            60         A
# 362254      362254  5904104            60         A
# 362257      362257  5904104            60         A
# 362261      362261  5904104            60         A
# ...            ...      ...           ...       ...
# 493140      493140  5904179             4         A
# 493141      493141  5904179             4         A
# 493142      493142  5904179             4         A
# 493143      493143  5904179             4         A
# 493144      493144  5904179             4         A
#
#                              DATE  DATE_QC LATITUDE LONGITUDE  POSITION_QC  \
# 362247 2014-01-04 02:18:30.000237        1  -63.566   155.593            1
# 362250 2014-01-04 02:18:30.000237        1  -63.566   155.593            1
# 362254 2014-01-04 02:18:30.000237        1  -63.566   155.593            1
# ...

# %%
pdf_yr[pdf_yr['CYCLE_NUMBER'] == 90]
# Out:
#         Unnamed: 0    WMOID  CYCLE_NUMBER DIRECTION  \
# 378645      378645  5904104            90         A
# 378648      378648  5904104            90         A
# 378652      378652  5904104            90         A
# 378655      378655  5904104            90         A
# 378659      378659  5904104            90         A
# ...            ...      ...           ...       ...
# 454975      454975  5904105            90         A
# 455001      455001  5904105            90         A
# 455027      455027  5904105            90         A
# 455053      455053  5904105            90         A
# 455068      455068  5904105            90         A
#
#                              DATE  DATE_QC LATITUDE LONGITUDE  POSITION_QC  \
# 378645 2014-08-04 06:26:51.000680        1  -62.053   152.694            8
# 378648 2014-08-04 06:26:51.000680        1  -62.053   152.694            8
# 378652 2014-08-04 06:26:51.000680        1  -62.053   152.694            8
# ...

# %%
 # writing function - can use to look at all data from productive month from one season (use function, then make depth profiles)
 # maybe work on how to make function that makes depth profiles instead of maps!
def subset_yr(df, season):
    
    subset = df[df['season'].isin([season])]
    # add subset by the productive months
    subset = subset[subset['month'].isin([1,2,3,4,8,9,10,11,12])]
    
    return subset

pdf_yr = subset_yr(pdf_clean,'2014.0-2015.0') # make sure you have in quotes and exact wording
pdf_yr
# Out:
#         Unnamed: 0    WMOID  CYCLE_NUMBER DIRECTION  \
# 378645      378645  5904104            90         A
# 378648      378648  5904104            90         A
# 378652      378652  5904104            90         A
# 378655      378655  5904104            90         A
# 378659      378659  5904104            90         A
# ...            ...      ...           ...       ...
# 468548      468548  5904105           127         A
# 468574      468574  5904105           127         A
# 468600      468600  5904105           127         A
# 468626      468626  5904105           127         A
# 468642      468642  5904105           127         A
#
#                              DATE  DATE_QC LATITUDE LONGITUDE  POSITION_QC  \
# 378645 2014-08-04 06:26:51.000680        1  -62.053   152.694            8
# 378648 2014-08-04 06:26:51.000680        1  -62.053   152.694            8
# 378652 2014-08-04 06:26:51.000680        1  -62.053   152.694            8
# ...

# %%
# FUNCTION FOR TRAJECTORY & CHLOROPHYLL CONCENTRATION
def traj_yr(df, season):
    
    
    #subset to productive months
    df = df[df['season'].isin([season])]
    
    #assign discrete colors
    unique_wmo = sorted(df['WMOID'].unique())
    n_wmo = len(unique_wmo)
    cmap = plt.get_cmap('plasma', n_wmo)
    
    # map each WMOID to an index for plotting
    wmo_to_idx = {wmo: i for i, wmo in enumerate(unique_wmo)}
    
    # convert WMOIDs to color indices
    color_indices = df['WMOID'].map(wmo_to_idx)
    
    #create figure and axis
    fig = plt.figure(figsize=(10, 7))
    # ax = plt.axes(projection=ccrs.PlateCarree())
    ax = fig.add_subplot(211, projection=ccrs.PlateCarree())
    
    # add basemap features
    ax.add_feature(cfeature.COASTLINE)
    ax.add_feature(cfeature.BORDERS, linestyle=':')
    ax.add_feature(cfeature.LAND, edgecolor='black', facecolor='lightgray')
    ax.add_feature(cfeature.OCEAN)
    
    #add profile locations
    sc = ax.scatter(df['LONGITUDE'], df['LATITUDE'],c=color_indices,
        cmap=cmap,s=50,transform=ccrs.PlateCarree(),edgecolor='k', linewidth=0.1)
    
    #unique axis label for each WMOID
    handles = [plt.Line2D([0], [0], marker='o', color='w', label=str(wmo),
                   markerfacecolor=cmap(i), markersize=10)
               for wmo, i in wmo_to_idx.items()]
    #add legend (and can change where legend is)
    ax.legend(handles=handles,title="WMOID",
        loc="center right",
        bbox_to_anchor=(1.31, 0.5),
        ncol=1,
        frameon=False)
    
    # labels
    # lon_ticks = np.arange(150, 181, 5)
    # lat_ticks = np.arange(-70, -55, 2)

    lon_ticks = np.arange(145, 170, 5)
    lat_ticks = np.arange(-70, -56, 2)
    
    ax.set_xticks(lon_ticks, crs=ccrs.PlateCarree())
    ax.set_yticks(lat_ticks, crs=ccrs.PlateCarree())
    ax.xaxis.set_major_formatter(LongitudeFormatter(zero_direction_label=True))
    ax.yaxis.set_major_formatter(LatitudeFormatter())
    
    ax.set_title(f'Float Trajectories ({season})', fontsize=14)
    ax.set_xlabel('Longitude')
    ax.set_ylabel('Latitude')

    
    # second plot of CHLA concentration --------------------------------------------------------------------------

    ax = fig.add_subplot(212, projection=ccrs.PlateCarree())
    
    # add basemap features
    ax.add_feature(cfeature.COASTLINE)
    ax.add_feature(cfeature.BORDERS, linestyle=':')
    ax.add_feature(cfeature.LAND, edgecolor='black', facecolor='lightgray')
    ax.add_feature(cfeature.OCEAN)
    
    #add profile locations
    df_chla = (df.loc[df.groupby(['WMOID', 'CYCLE_NUMBER'])['CHLA_ADJUSTED'].idxmax()])
    
    
    sc = ax.scatter(df_chla['LONGITUDE'], df_chla['LATITUDE'],c=df_chla['CHLA_ADJUSTED'],
        cmap='viridis',s=50,transform=ccrs.PlateCarree(),norm=LogNorm(vmin=0.1, vmax=8), edgecolor='k', linewidth=0.1)
    
    # labels
    # lon_ticks = np.arange(150, 181, 5)
    # lat_ticks = np.arange(-70, -55, 2)

    lon_ticks = np.arange(145, 170, 5)
    lat_ticks = np.arange(-70, -56, 2)
    
    ax.set_xticks(lon_ticks, crs=ccrs.PlateCarree())
    ax.set_yticks(lat_ticks, crs=ccrs.PlateCarree())
    ax.xaxis.set_major_formatter(LongitudeFormatter(zero_direction_label=True))
    ax.yaxis.set_major_formatter(LatitudeFormatter())
    
    ax.set_title(f'Float Trajectories ({season})', fontsize=14)
    ax.set_xlabel('Longitude')
    ax.set_ylabel('Latitude')

    cbar = plt.colorbar(sc, ax=ax, orientation='vertical', pad=0.055,shrink=1)
    cbar.set_label('Log Chl-a (mg m$^{-3}$)')
    cbar.locator = LogLocator(base=10, subs=(1, 2, 5))
    cbar.formatter = FormatStrFormatter("%.1f")
    cbar.update_ticks()
    
    plt.tight_layout()
    plt.show()

    
    # add save path for pic
    # fig.savefig(f'/Users/lilah/Documents/IBIS_Project/Figures/float_trajectories_{season}.png') #uncomment for lilah
    # fig.savefig(f'/Users/steviewalker/Documents/IBIS_Project/Figures/float_trajectories_{season}.png') #uncomment for stevie
    # can plot surface CHLA on map to detect bloom/year

traj_yr(df = pdf_clean, season = '2014.0-2015.0')

# %%
# FUNCTION FOR CYCLE NUMBER WITH TRAJECTORY & CHLOROPHYLL CONCENTRATION
def traj_yr_cycle(df, season, WMOID):
    
    
    #subset to productive months
    df = df[df['season'].isin([season])]
    df = df[df['WMOID'] == WMOID]
    
    #assign discrete colors
    unique_cycle = sorted(df['CYCLE_NUMBER'].unique())
    n_cycle = len(unique_cycle)
    cmap = plt.get_cmap('Spectral', n_cycle)
    
    # map each WMOID to an index for plotting
    cycle_to_idx = {cycle: i for i, cycle in enumerate(unique_cycle)}
    
    # convert WMOIDs to color indices
    color_indices = df['CYCLE_NUMBER'].map(cycle_to_idx)
    
    #create figure and axis
    fig = plt.figure(figsize=(10, 7))
    # ax = plt.axes(projection=ccrs.PlateCarree())
    ax = fig.add_subplot(211, projection=ccrs.PlateCarree())
    
    # add basemap features
    ax.add_feature(cfeature.COASTLINE)
    ax.add_feature(cfeature.BORDERS, linestyle=':')
    ax.add_feature(cfeature.LAND, edgecolor='black', facecolor='lightgray')
    ax.add_feature(cfeature.OCEAN)
    
    #add profile locations
    sc = ax.scatter(df['LONGITUDE'], df['LATITUDE'],c=color_indices,
        cmap=cmap,s=50,transform=ccrs.PlateCarree(),edgecolor='k', linewidth=0.1)
    
    #unique axis label for each WMOID
    handles = [plt.Line2D([0], [0], marker='o', color='w', label=str(cycle),
                   markerfacecolor=cmap(i), markersize=10)
               for cycle, i in cycle_to_idx.items()]
    #add legend (and can change where legend is)
    ax.legend(handles=handles,title="CYCLE_NUMBER",
        loc="center right",
        bbox_to_anchor=(1.5, 0.5),
        ncol=3,
        frameon=False)
    
    # labels
    lon_ticks = np.arange(150, 181, 5)
    lat_ticks = np.arange(-70, -55, 2)
    ax.set_xticks(lon_ticks, crs=ccrs.PlateCarree())
    ax.set_yticks(lat_ticks, crs=ccrs.PlateCarree())
    ax.xaxis.set_major_formatter(LongitudeFormatter(zero_direction_label=True))
    ax.yaxis.set_major_formatter(LatitudeFormatter())
    
    ax.set_title(f'Float Trajectories WMO {WMOID} ({season})', fontsize=14)
    ax.set_xlabel('Longitude')
    ax.set_ylabel('Latitude')

    
    # second plot of CHLA concentration --------------------------------------------------------------------------

    ax = fig.add_subplot(212, projection=ccrs.PlateCarree())
    
    # add basemap features
    ax.add_feature(cfeature.COASTLINE)
    ax.add_feature(cfeature.BORDERS, linestyle=':')
    ax.add_feature(cfeature.LAND, edgecolor='black', facecolor='lightgray')
    ax.add_feature(cfeature.OCEAN)
    
    #add profile locations
    df_chla = (df.loc[df.groupby(['WMOID', 'CYCLE_NUMBER'])['CHLA_ADJUSTED'].idxmax()])
    
    
    sc = ax.scatter(df_chla['LONGITUDE'], df_chla['LATITUDE'],c=df_chla['CHLA_ADJUSTED'],
        cmap='viridis',s=50,transform=ccrs.PlateCarree(),norm=LogNorm(vmin=0.1, vmax=8), edgecolor='k', linewidth=0.1)
    
    # labels
    lon_ticks = np.arange(150, 181, 5)
    lat_ticks = np.arange(-70, -55, 2)
    ax.set_xticks(lon_ticks, crs=ccrs.PlateCarree())
    ax.set_yticks(lat_ticks, crs=ccrs.PlateCarree())
    ax.xaxis.set_major_formatter(LongitudeFormatter(zero_direction_label=True))
    ax.yaxis.set_major_formatter(LatitudeFormatter())
    
    ax.set_title(f'Float Trajectories WMO {WMOID} ({season})', fontsize=14)
    ax.set_xlabel('Longitude')
    ax.set_ylabel('Latitude')

    cbar = plt.colorbar(sc, ax=ax, orientation='vertical', pad=0.055,shrink=1)
    cbar.set_label('Log Chl-a (mg m$^{-3}$)')
    cbar.locator = LogLocator(base=10, subs=(1, 2, 5))
    cbar.formatter = FormatStrFormatter("%.1f")
    cbar.update_ticks()
    
    plt.tight_layout()
    plt.show()

    
    # add save path for pic
    # fig.savefig(f'/Users/lilah/Documents/IBIS_Project/Figures/float_trajectories_{season}_cyclenum.png') #uncomment for lilah
    # fig.savefig(f'/Users/steviewalker/Documents/IBIS_Project/Figures/float_trajectories_{season}.png') #uncomment for stevie
    # can plot surface CHLA on map to detect bloom/year

traj_yr_cycle(df = pdf_clean, season = '2014.0-2015.0', WMOID = 5904104)

# %%
 # writing function - can use to look at all data from productive month from one season (use function, then make depth profiles)
 # maybe work on how to make function that makes depth profiles instead of maps!
def subset_yr(df, season1, season2):

    # subset for 2014
    subset = df[df['season1'].isin([season1])]
    # add subset by the productive months
    subset = subset[subset['month'].isin([7,8,9,10,11,12])]

    # subset for 2015
    subset = df[df['season2'].isin([season2])]
    # add subset by the productive months
    subset = subset[subset['month'].isin([1,2,3,4,5,6])]

    return subset

pdf_yr = subset_yr(pdf_clean,'2014', '2015') # make sure you have in quotes and exact wording
pdf_yr
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /opt/anaconda3/envs/IBIS_Project/lib/python3.13/site-packages/pandas/core/indexes/base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'season1'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[82], line 17
# ...

# %%
pdf_yr
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[80], line 1
# ----> 1 pdf_yr
#
# NameError: name 'pdf_yr' is not defined

# %%
 # writing function
def subset_year(df, yr1,yr2):
    
    subset = df[df['year'].isin([yr1,yr2])]
    # add subset by the productive months
    # subset = subset[subset['month'].isin([1,2,3,4,10,11,12])]
    
    return subset

pdf_year = subset_year(pdf,2014,2015)
pdf_year
# Out:
#         Unnamed: 0    WMOID  CYCLE_NUMBER DIRECTION  \
# 423            423  1901155           145         A
# 424            424  1901155           145         A
# 425            425  1901155           145         A
# 426            426  1901155           145         A
# 427            427  1901155           145         A
# ...            ...      ...           ...       ...
# 545191      545191  5904598            39         A
# 545192      545192  5904598            39         A
# 545193      545193  5904598            39         A
# 545194      545194  5904598            39         A
# 545195      545195  5904598            39         A
#
#                              DATE  DATE_QC LATITUDE LONGITUDE  POSITION_QC  \
# 423    2015-01-02 04:48:22.000017        1  -59.747   169.637            1
# 424    2015-01-02 04:48:22.000017        1  -59.747   169.637            1
# 425    2015-01-02 04:48:22.000017        1  -59.747   169.637            1
# ...

# %%
pdf_year['year'].min()
# Out:
# 2014.0

# %%
# Condition 1: July-Dec 2014
cond1 = (pdf_clean['year'] == 2014) & (pdf_clean['month'] >= 7)

# Condition 2: Jan-June 2015
cond2 = (pdf_clean['year'] == 2015) & (pdf_clean['month'] <= 6)

# Combine them with "OR" (|)
subset_df = pdf_clean[cond1 | cond2]
subset_df['month']
# Out:
# 376487    7.0
# 376490    7.0
# 376494    7.0
# 376497    7.0
# 376501    7.0
#          ...
# 472894    6.0
# 472920    6.0
# 472946    6.0
# 472972    6.0
# 472987    6.0
# Name: month, Length: 4734, dtype: float64

# %%
def traj_yr_wmo(df, wmo_val): # Renamed argument to wmo_val to avoid confusion
    
    # 1. Filter the dataframe to ONLY the specific float first
    # Replace 'WMOID' with the actual string name of your column
    df_single = df[df['WMOID'] == wmo_val].copy() 
    
    fig = plt.figure(figsize=(20, 20))
    ax = plt.axes(projection=ccrs.PlateCarree())
    
    # add basemap features
    ax.add_feature(cfeature.COASTLINE)
    ax.add_feature(cfeature.BORDERS, linestyle=':')
    ax.add_feature(cfeature.LAND, edgecolor='black', facecolor='lightgray')
    ax.add_feature(cfeature.OCEAN)

    # 2. Use the SUBSET (df_single) for your calculations, not the original 'df'
    # This ensures ONLY the specified WMOID data is processed
    df_chla = (df_single.loc[df_single.groupby(['WMOID', 'CYCLE_NUMBER'])['CHLA_ADJUSTED'].idxmax()])

    # 3. Use the filtered df_chla for the scatter plot
    sc = ax.scatter(df_chla['LONGITUDE'], 
                    df_chla['LATITUDE'],
                    c=df_chla['CHLA_ADJUSTED'], 
                    cmap='viridis',
                    s=250,
                    transform=ccrs.PlateCarree(),
                    norm=LogNorm(vmin=0.1, vmax=8), 
                    edgecolor='k', 
                    linewidth=0.1)

     # labels
    lon_ticks = np.arange(142, 172, 5)
    lat_ticks = np.arange(-67, -52, 2)
    ax.set_xticks(lon_ticks, crs=ccrs.PlateCarree())
    ax.set_yticks(lat_ticks, crs=ccrs.PlateCarree())
    ax.xaxis.set_major_formatter(LongitudeFormatter(zero_direction_label=True))
    ax.yaxis.set_major_formatter(LatitudeFormatter())
    ax.tick_params(axis='both', pad =14, labelsize=30)
    
    ax.set_title(f'Float 5904104 Trajectory', fontsize=60, pad = 25)
    ax.set_xlabel('Longitude', fontsize=38)
    ax.set_ylabel('Latitude', fontsize=38)
   
    
    cbar = plt.colorbar(sc, ax=ax, orientation='vertical', pad=0.05,shrink=0.5)
    cbar.set_label('Log Chl-a (mg m$^{-3}$)', fontsize = 35)
    cbar.locator = LogLocator(base=10, subs=(1, 2, 5))
    cbar.formatter = FormatStrFormatter("%.1f")
    cbar.ax.tick_params(labelsize=35, pad = 14) 
    cbar.update_ticks()

        
    plt.tight_layout()
    plt.show()

    fig.savefig(f'/Users/lilah/Documents/IBIS_Project/Figures/float_traj_4_2014-15.svg', dpi = 300, bbox_inches='tight')
            

traj_yr_wmo(df = subset_df, wmo_val= 5904104)

# %%
def traj_yr_wmo(df, season, WMOID):
    
    
    #subset to productive months
    df = df[df['season'].isin([season])]

    fig = plt.figure(figsize=(8, 8))
    ax = plt.axes(projection=ccrs.PlateCarree())
    
    # add basemap features
    ax.add_feature(cfeature.COASTLINE)
    ax.add_feature(cfeature.BORDERS, linestyle=':')
    ax.add_feature(cfeature.LAND, edgecolor='black', facecolor='lightgray')
    ax.add_feature(cfeature.OCEAN)
    
    #add profile locations -----------------
    df_chla = (df.loc[df.groupby(['WMOID', 'CYCLE_NUMBER'])['CHLA_ADJUSTED'].idxmax()])
    
    
    # for eddy profile 
    # eddy_wmoid = 5906581
    # df_eddy = df[df['WMOID'] == eddy_wmoid]
    # df_chla = (df_eddy.loc[df_eddy.groupby(['WMOID', 'CYCLE_NUMBER'])['CHLA_ADJUSTED'].idxmax()])
    
    df_1 = df[df['WMOID'] == WMOID]
    # df_chla = (df_1.loc[df_1.groupby(['WMOID', 'CYCLE_NUMBER'])['CHLA_ADJUSTED'].idxmax()]) # this is for DCM
    #get chla at 5 dbar in all profiles, this is for surface chla
    df_surface = (df_chla.loc[df_chla.groupby(['WMOID', 'CYCLE_NUMBER'])['PRES_ADJUSTED'].apply(lambda x: (x - 5).abs().idxmin())])
    
    
    sc = ax.scatter(df_chla['LONGITUDE'], df_chla['LATITUDE'],c=df_chla['CHLA_ADJUSTED'],
        cmap='viridis',s=60,transform=ccrs.PlateCarree(),norm=LogNorm(vmin=0.1, vmax=8), edgecolor='k', linewidth=0.1)
    
    # labels
    lon_ticks = np.arange(145, 170, 5)
    lat_ticks = np.arange(-70, -50, 2)
    ax.set_xticks(lon_ticks, crs=ccrs.PlateCarree())
    ax.set_yticks(lat_ticks, crs=ccrs.PlateCarree())
    ax.xaxis.set_major_formatter(LongitudeFormatter(zero_direction_label=True))
    ax.yaxis.set_major_formatter(LatitudeFormatter())
    
    ax.set_title(f'Float Trajectory WMO {WMOID} ({season})', fontsize=14)
    ax.set_xlabel('Longitude')
    ax.set_ylabel('Latitude')
   
    
    cbar = plt.colorbar(sc, ax=ax, orientation='vertical', pad=0.11,shrink=0.5)
    cbar.set_label('Log Chl-a (mg m$^{-3}$)')
    cbar.locator = LogLocator(base=10, subs=(1, 2, 5))
    cbar.formatter = FormatStrFormatter("%.1f")
    cbar.update_ticks()

        
    plt.tight_layout()
    plt.show()

# traj_yr_wmo(df = pdf_clean, season = '2014.0-2015.0', WMOID= 5904105)
traj_yr_wmo(df = pdf_clean, season = '2014.0-2015.0', WMOID= 5904104)

# %%
# FUNCTION FOR PHYSICAL PROPERTIES

def phys_prop(df, season, WMOID, cycle_num):

     #subset to productive months
    df = df[df['season'].isin([season])]
    df = df[df['WMOID'].isin([WMOID])]
    df = df[df['CYCLE_NUMBER'].isin([cycle_num])]
    
    df['DATE'] = pd.to_datetime(df['DATE'])
    date_nums = mdates.date2num(df['DATE'])

    # calculating physical properties ----------------------------------------------------------
    long = np.array(df['LONGITUDE']).astype(float)
    lat = np.array(df['LATITUDE']).astype(float)

    
    # calculating absolute salinity 
    abs_sal = gsw.conversions.SA_from_SP(df['PSAL'], df['PRES'], long, lat)
    
    # calculating conservative temperature
    cons_temp = gsw.CT_from_t(abs_sal, df['TEMP'], df['PRES'])
    
    #calculating potential density
    sigma0 = gsw.sigma0(abs_sal, cons_temp)
    p_density = sigma0 + 1000
    
    # calculating depths from pressure for each cycle/
    depth = gsw.conversions.z_from_p(df['PRES_ADJUSTED'].values, lat)
    
    # making depths positive (convention of y axis being inverted and values being positive)
    depth_pos = abs(depth)

    # making figures --------------------------------------------------------------------------
    fig = plt.figure(figsize=(16,8))

    x1 = cons_temp
    x2 = abs_sal
    x3 = p_density
    y = depth_pos

    # conservative temperature -------------
    ax = fig.add_subplot(131)
    ax.plot(x1, y, c='mediumvioletred', lw =2)
    ax.invert_yaxis()

    ax.set_xlabel(r'Temperature ($^\circ$C)', fontsize=12)
    ax.set_ylabel('Depth (m)', fontsize=12)
    ax.set_title('Conservative Temperature', fontsize=14)

    # asbolute salinity -------------------
    ax = fig.add_subplot(132)
    ax.plot(x2, y, c='darkturquoise', ls ='--', lw = 2)
    ax.invert_yaxis()

    ax.set_xlabel(r'Bbp (m$^{-1}$)', fontsize=12)
    ax.set_ylabel('Depth (m)', fontsize=12)
    ax.set_title('Absolute Salinity', fontsize=14)

    # potential density -------------------
    ax = fig.add_subplot(133)
    ax.plot(x3, y, c='seagreen', ls = ':', lw = 2.4)
    ax.invert_yaxis()

    ax.set_xlabel(r'Density ($\mathregular{kg/m^3}$)', fontsize=12)
    ax.set_ylabel('Depth (m)', fontsize=12)
    ax.set_title('Potential Density', fontsize=14)

    plt.subplots_adjust(hspace=0.5, wspace=0.4)

phys_prop(df = pdf_clean, season = '2014.0-2015.0', WMOID = 5904105, cycle_num = 108)

# %%
#  FUNCTION FOR DEPTH PROFILES

def prof_yr(df, season, WMOID):
    
    #subset to productive months
    df = df[df['season'].isin([season])]
    df = df[df['WMOID'].isin([WMOID])]
    
    df['DATE'] = pd.to_datetime(df['DATE'])
    date_nums = mdates.date2num(df['DATE'])
    
    # Shared normalization and colormap
    norm = mcolors.Normalize(vmin=date_nums.min(), vmax=date_nums.max())
    cmap = plt.get_cmap('plasma', len(df['DATE'].unique()))
    
    # Create figure and axis
    fig = plt.figure(figsize=(16,7), layout='constrained')
    
    # Chlorophyll profile -----------------------------------------------------------------
    ax = fig.add_subplot(141)
    for cycle, group in df.groupby('CYCLE_NUMBER'):
        date_val = mdates.date2num(group['DATE'].iloc[0])
        color = cmap(norm(date_val))
        ax.plot(group['CHLA_ADJUSTED'], group['PRES_ADJUSTED'], color=color, lw=2)
    
    # ax.set_xlim(0, 7)
    ax.set_ylim(0, 200)
    ax.invert_yaxis()
    ax.set_xlabel('Chl-a (mg m$^{-3}$)', fontsize=12)
    ax.set_ylabel('Pressure (dbar)', fontsize=12)
    ax.set_title(f'WMO {str(WMOID)} Chl-a Profiles', fontsize=14)

    # ADD ADDITIONAL VARIABLES HERE (nitrate, oxygen, bbp, nitrate, t, s, etc) ---------------
    # Oxygen profile ------------------------------------------------------------------------
    ax = fig.add_subplot(142)
    for cycle, group in df.groupby('CYCLE_NUMBER'):
        date_val = mdates.date2num(group['DATE'].iloc[0])
        color = cmap(norm(date_val))
        ax.plot(group['DOXY_ADJUSTED'], group['PRES_ADJUSTED'], color=color, lw=2)

    # ax.set_ylim(0, 1000)
    ax.invert_yaxis()
    ax.set_xlabel(r'Oxygen ($\mu\text{mol/kg}$)', fontsize=12)
    ax.set_ylabel('Pressure (dbar)', fontsize=12)
    ax.set_title(f'WMO {str(WMOID)} Oxygen Profiles', fontsize=14)

    # BBP profile ----------------------------------------------------------------------------
    ax = fig.add_subplot(143)
    for cycle, group in df.groupby('CYCLE_NUMBER'):
        date_val = mdates.date2num(group['DATE'].iloc[0])
        color = cmap(norm(date_val))
        ax.plot(group['BBP700_ADJUSTED'], group['PRES_ADJUSTED'], color=color, lw=2)

    # ax.set_ylim(0, 1000)
    ax.invert_yaxis()
    ax.set_xlabel(r'$b_{bp}$ [$m^{-1}$]', fontsize=12)
    ax.set_ylabel('Pressure (dbar)', fontsize=12)
    ax.set_title(f'WMO {str(WMOID)} Backscatter Profiles', fontsize=14)

    # Nitrate profile ---------------------------------------------------------------------
    ax = fig.add_subplot(144)
    for cycle, group in df.groupby('CYCLE_NUMBER'):
        date_val = mdates.date2num(group['DATE'].iloc[0])
        color = cmap(norm(date_val))
        ax.plot(group['NITRATE_ADJUSTED'], group['PRES_ADJUSTED'], color=color, lw=2)

    # ax.set_ylim(0, 1000)
    ax.invert_yaxis()
    ax.set_xlabel(r'Nitrate ($\mu\text{mol/kg}$', fontsize=12)
    ax.set_ylabel('Pressure (dbar)', fontsize=12)
    ax.set_title(f'WMO {str(WMOID)} Nitrate Profiles', fontsize=14)
    
    #add colorbar
    sm = cm.ScalarMappable(norm=norm, cmap=cmap)
    sm.set_array([])
    cbar = fig.colorbar(sm, ax=ax, orientation='vertical', label='Date')
    
    tick_locs = np.linspace(date_nums.min(), date_nums.max(), 10)
    cbar.set_ticks(tick_locs)
    cbar.ax.yaxis.set_major_formatter(mdates.DateFormatter('%m-%d-%y'))
    plt.show()

    #save profile
    fig.savefig(f'/Users/lilah/Documents/IBIS_Project/Figures/float_trajectories_depth{season}.png') #uncomment for lilah
    # fig.savefig(f'/Users/steviewalker/Documents/IBIS_Project/Figures/chla_profile_timeseries_WMO{WMOID}_{season}.png') #uncomment for stevie

prof_yr(df = pdf_clean, season = '2014.0-2015.0',WMOID = 5904105)
prof_yr(df = pdf_clean, season = '2014.0-2015.0',WMOID = 5904104)

# %%
# MEGA FUNCTION FOR DEPTH PROFILES & PHYSICAL PROPERTIES: CHLA, OXYGEN, BACKSCATTER, CONSERVATIVE TEMPERATURE, ABSOLUTE SALINITY & POTENTIAL DENSITY

def prof_phys(df, season, WMOID, cycle_num):

    # FUNCTION FOR DEPTH PROFILES ---------------------------------------------------------------------------------------------
    
    #subset to productive months
    df = df[df['season'].isin([season])]
    df = df[df['WMOID'].isin([WMOID])]
    
    df['DATE'] = pd.to_datetime(df['DATE'])
    date_nums = mdates.date2num(df['DATE'])
    
    # Shared normalization and colormap
    norm = mcolors.Normalize(vmin=date_nums.min(), vmax=date_nums.max())
    cmap = plt.get_cmap('plasma', len(df['DATE'].unique()))
    
    # Create figure and axis
    fig = plt.figure(figsize=(13,7),layout='constrained')
    
    # Chlorophyll profile -----------------------------------------------------------------
    ax = fig.add_subplot(131)
    for cycle, group in df.groupby('CYCLE_NUMBER'):
        date_val = mdates.date2num(group['DATE'].iloc[0])
        color = cmap(norm(date_val))
        ax.plot(group['CHLA_ADJUSTED'], group['PRES_ADJUSTED'], color=color, lw=2)
    
    # ax.set_xlim(0, 7)
    ax.set_ylim(0, 200)
    ax.invert_yaxis()
    ax.set_xlabel('Chl-a (mg m$^{-3}$)', fontsize=12)
    ax.set_ylabel('Pressure (dbar)', fontsize=12)
    ax.set_title(f'WMO {str(WMOID)} Chl-a Profiles', fontsize=14)

    # ADD ADDITIONAL VARIABLES HERE (nitrate, oxygen, bbp, nitrate, t, s, etc) ---------------
    # Oxygen profile ------------------------------------------------------------------------
    ax = fig.add_subplot(132)
    for cycle, group in df.groupby('CYCLE_NUMBER'):
        date_val = mdates.date2num(group['DATE'].iloc[0])
        color = cmap(norm(date_val))
        ax.plot(group['DOXY_ADJUSTED'], group['PRES_ADJUSTED'], color=color, lw=2)

    # ax.set_ylim(0, 1000)
    ax.invert_yaxis()
    ax.set_xlabel(r'Oxygen ($\mu\text{mol/kg}$)', fontsize=12)
    ax.set_ylabel('Pressure (dbar)', fontsize=12)
    ax.set_title(f'WMO {str(WMOID)} Oxygen Profiles', fontsize=14)

    # BBP profile ----------------------------------------------------------------------------
    ax = fig.add_subplot(133)
    for cycle, group in df.groupby('CYCLE_NUMBER'):
        date_val = mdates.date2num(group['DATE'].iloc[0])
        color = cmap(norm(date_val))
        ax.plot(group['BBP700_ADJUSTED'], group['PRES_ADJUSTED'], color=color, lw=2)

    # ax.set_ylim(0, 1000)
    ax.invert_yaxis()
    ax.set_xlabel(r'$b_{bp}$ [$m^{-1}$]', fontsize=12)
    plt.xticks(rotation=45, ha='right')
    ax.set_ylabel('Pressure (dbar)', fontsize=12)
    ax.set_title(f'WMO {str(WMOID)} Backscatter Profiles', fontsize=14)
    
    #add colorbar
    sm = cm.ScalarMappable(norm=norm, cmap=cmap)
    sm.set_array([])
    cbar = fig.colorbar(sm, ax=ax, orientation='vertical', label='Date')
    
    tick_locs = np.linspace(date_nums.min(), date_nums.max(), 10)
    cbar.set_ticks(tick_locs)
    cbar.ax.yaxis.set_major_formatter(mdates.DateFormatter('%m-%d-%y'))

    plt.subplots_adjust(hspace=0.5, wspace=0.8)
    plt.show()

    # FUNCTION FOR PHYSICAL PROPERTIES -----------------------------------------------------------------------------------------------

    df = df[df['CYCLE_NUMBER'].isin([cycle_num])]

    # calculating physical properties ----------------------------------------------------------
    long = np.array(df['LONGITUDE']).astype(float)
    lat = np.array(df['LATITUDE']).astype(float)

    
    # calculating absolute salinity 
    abs_sal = gsw.conversions.SA_from_SP(df['PSAL'], df['PRES'], long, lat)
    
    # calculating conservative temperature
    cons_temp = gsw.CT_from_t(abs_sal, df['TEMP'], df['PRES'])
    
    #calculating potential density
    sigma0 = gsw.sigma0(abs_sal, cons_temp)
    p_density = sigma0 + 1000
    
    # calculating depths from pressure for each cycle/
    depth = gsw.conversions.z_from_p(df['PRES_ADJUSTED'].values, lat)
    
    # making depths positive (convention of y axis being inverted and values being positive)
    depth_pos = abs(depth)

    # making figures --------------------------------------------------------------------------
    fig = plt.figure(figsize=(16,18))

    x1 = cons_temp
    x2 = abs_sal
    x3 = p_density
    y = depth_pos

    # conservative temperature -------------
    ax = fig.add_subplot(231)
    ax.plot(x1, y, c='mediumvioletred', lw =2)
    ax.invert_yaxis()

    ax.set_xlabel(r'Temperature ($^\circ$C)', fontsize=12)
    ax.set_ylabel('Depth (m)', fontsize=12)
    ax.set_title(f'WMO {str(WMOID)} Conservative Temperature', fontsize=14)

    # asbolute salinity -------------------
    ax = fig.add_subplot(232)
    ax.plot(x2, y, c='darkturquoise', ls ='--', lw = 2)
    ax.invert_yaxis()

    ax.set_xlabel(r'Bbp (m$^{-1}$)', fontsize=12)
    ax.set_ylabel('Depth (m)', fontsize=12)
    ax.set_title(f'WMO {str(WMOID)} Absolute Salinity', fontsize=14)

    # potential density -------------------
    ax = fig.add_subplot(233)
    ax.plot(x3, y, c='seagreen', ls = ':', lw = 2.4)
    ax.invert_yaxis()

    ax.set_xlabel(r'Density ($\mathregular{kg/m^3}$)', fontsize=12)
    ax.set_ylabel('Depth (m)', fontsize=12)
    ax.set_title(f'WMO {str(WMOID)} Potential Density', fontsize=14)

    plt.subplots_adjust(hspace=0.5, wspace=0.4)

    #save profile
    fig.savefig(f'/Users/lilah/Documents/IBIS_Project/Figures/float_trajectories_depth_phys{season}.png') #uncomment for lilah
    # fig.savefig(f'/Users/steviewalker/Documents/IBIS_Project/Figures/chla_profile_timeseries_WMO{WMOID}_{season}.png') #uncomment for stevie

prof_phys(df = pdf_clean, season = '2015.0-2016.0',WMOID = 5904104, cycle_num = 160)
# Out:
# /var/folders/sr/nn_fjjln6s33md98tyfc3rd40000gn/T/ipykernel_58484/628478267.py:72: UserWarning: This figure was using a layout engine that is incompatible with subplots_adjust and/or tight_layout; not calling subplots_adjust.
#   plt.subplots_adjust(hspace=0.5, wspace=0.8)

# %%
# FUNCTION FOR SECTION PLOTS WITH SEASON & WMOID
def sections(df, season, WMOID, variable):

    df = df[df['season'].isin([season])]
    df = df[df['WMOID'].isin([WMOID])]
    
    
    fig = plt.figure(figsize=(16,18))
    ax = argo.sections(df, variable)
    ax.set_ylim(200, 0)


    #save profile
    # fig.savefig(f'/Users/lilah/Documents/IBIS_Project/Figures/float_trajectories_depth_phys{season}.png') #uncomment for lilah
    # fig.savefig(f'/Users/steviewalker/Documents/IBIS_Project/Figures/chla_profile_timeseries_WMO{WMOID}_{season}.png') #uncomment for stevie

sections(df = chla_df, season = '2014.0-2015.0', WMOID = 5904104, variable = 'CHLA_ADJUSTED')
# Out:
# Validating passed 'variables'...
# Validating passed float_data_dataframe...
# Generating section plots for float 5904104...
# Generating CHLA_ADJUSTED section plot for float 5904104...
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[393], line 17
#      10     ax.set_ylim(200, 0)
#      13     #save profile
#      14     # fig.savefig(f'/Users/lilah/Documents/IBIS_Project/Figures/float_trajectories_depth_phys{season}.png') #uncomment for lilah
#      15     # fig.savefig(f'/Users/steviewalker/Documents/IBIS_Project/Figures/chla_profile_timeseries_WMO{WMOID}_{season}.png') #uncomment for stevie
# ---> 17 sections(df = chla_df, season = '2014.0-2015.0', WMOID = 5904104, variable = 'CHLA_ADJUSTED')
#
# Cell In[393], line 10, in sections(df, season, WMOID, variable)
#       8 fig = plt.figure(figsize=(16,18))
#       9 ax = argo.sections(df, variable)
# ...

# %%
def prof_yr(df, season):
    
    
    #subset to productive months
    df = df[df['season'].isin([season])]

    WMOID = 5904104
    df['DATE'] = pd.to_datetime(df['DATE'])
    date_nums = mdates.date2num(df['DATE'])
    
    # Shared normalization and colormap
    norm = mcolors.Normalize(vmin=date_nums.min(), vmax=date_nums.max())
    cmap = plt.get_cmap('plasma', len(df['DATE'].unique()))
    
    # Create figure and axis
    fig = plt.figure(figsize=(5,7), layout='constrained')
    
    # chla ---------------
    ax = fig.add_subplot(111)
    for cycle, group in df.groupby('CYCLE_NUMBER'):
        date_val = mdates.date2num(group['DATE'].iloc[0])
        color = cmap(norm(date_val))
        ax.plot(group['CHLA_ADJUSTED'], group['PRES_ADJUSTED'], color=color, lw=2)
    
    # ax.set_xlim(0, 7)
    ax.set_ylim(0, 200)
    ax.invert_yaxis()
    ax.set_xlabel('Chl-a (mg m$^{-3}$)', fontsize=12)
    ax.set_ylabel('Pressure (dbar)', fontsize=12)
    ax.set_title(f'WMO {str(WMOID)} Chl-a Profiles', fontsize=14)
    
    sm = cm.ScalarMappable(norm=norm, cmap=cmap)
    sm.set_array([])
    
    cbar = fig.colorbar(sm, ax=ax, orientation='vertical', label='Date')
    
    tick_locs = np.linspace(date_nums.min(), date_nums.max(), 10)
    cbar.set_ticks(tick_locs)
    cbar.ax.yaxis.set_major_formatter(mdates.DateFormatter('%m-%d-%y'))
    plt.show()

prof_yr(df = pdf_clean, season = '2014.0-2015.0')
# Out:
# /var/folders/sr/nn_fjjln6s33md98tyfc3rd40000gn/T/ipykernel_58484/1495218190.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['DATE'] = pd.to_datetime(df['DATE'])

# %%
pdf["year"] = pdf["DATE"].dt.year
pdf["month"] = pdf["DATE"].dt.month

# %%
#updated code from Stevie

WMOID = 5906624 
pdf_WMO['DATE'] = pd.to_datetime(pdf_WMO['DATE'])
date_nums = mdates.date2num(pdf_WMO['DATE'])

# Shared normalization and colormap
norm = mcolors.Normalize(vmin=date_nums.min(), vmax=date_nums.max())
cmap = plt.get_cmap('plasma', len(pdf_WMO['DATE'].unique()))

# Create figure and axis
fig = plt.figure(figsize=(5,7), layout='constrained')

# chla ---------------
ax = fig.add_subplot(111)
for cycle, group in pdf_WMO.groupby('CYCLE_NUMBER'):
    date_val = mdates.date2num(group['DATE'].iloc[0])
    color = cmap(norm(date_val))
    ax.plot(group['CHLA_ADJUSTED'], group['PRES_ADJUSTED'], color=color, lw=2)

# ax.set_xlim(0, 7)
ax.set_ylim(0, 200)
ax.invert_yaxis()
ax.set_xlabel('Chl-a (mg m$^{-3}$)', fontsize=12)
ax.set_ylabel('Pressure (dbar)', fontsize=12)
ax.set_title(f'WMO {str(WMOID)} Chl-a Profiles', fontsize=14)

sm = cm.ScalarMappable(norm=norm, cmap=cmap)
sm.set_array([])

cbar = fig.colorbar(sm, ax=ax, orientation='vertical', label='Date')

tick_locs = np.linspace(date_nums.min(), date_nums.max(), 10)
cbar.set_ticks(tick_locs)
cbar.ax.yaxis.set_major_formatter(mdates.DateFormatter('%m-%d-%y'))
plt.show()
# Out:
# /var/folders/cn/f7hyztf9023fy4lx2tlld0xh0000gn/T/ipykernel_51779/176985273.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pdf_WMO['DATE'] = pd.to_datetime(pdf_WMO['DATE'])

# %%
#  FUNCTION FOR DEPTH PROFILES

def prof_yr(df, season, WMOID):
    
    #subset to productive months
    df = df[df['season'].isin([season])]
    df = df[df['WMOID'].isin([WMOID])]
    
    df['DATE'] = pd.to_datetime(df['DATE'])
    date_nums = mdates.date2num(df['DATE'])
    
    # Shared normalization and colormap
    norm = mcolors.Normalize(vmin=date_nums.min(), vmax=date_nums.max())
    cmap = plt.get_cmap('plasma', len(df['DATE'].unique()))
    
    # Create figure and axis
    fig = plt.figure(figsize=(9,12), layout='constrained')
    
    # Chlorophyll profile -----------------------------------------------------------------
    ax = fig.add_subplot(221)
    for cycle, group in df.groupby('CYCLE_NUMBER'):
        date_val = mdates.date2num(group['DATE'].iloc[0])
        color = cmap(norm(date_val))
        ax.plot(group['CHLA_ADJUSTED'], group['PRES_ADJUSTED'], color=color, lw=2)
    
    # ax.set_xlim(0, 7)
    ax.set_ylim(0, 200)
    ax.invert_yaxis()
    ax.set_xlabel('Chl-a (mg m$^{-3}$)', fontsize=12)
    ax.set_ylabel('Pressure (dbar)', fontsize=12)
    ax.set_title(f'WMO {str(WMOID)} Chl-a Profiles', fontsize=14)

    # ADD ADDITIONAL VARIABLES HERE (nitrate, oxygen, bbp, nitrate, t, s, etc) ---------------
    # Oxygen profile ------------------------------------------------------------------------
    ax = fig.add_subplot(222)
    for cycle, group in df.groupby('CYCLE_NUMBER'):
        date_val = mdates.date2num(group['DATE'].iloc[0])
        color = cmap(norm(date_val))
        ax.plot(group['DOXY_ADJUSTED'], group['PRES_ADJUSTED'], color=color, lw=2)

    # ax.set_ylim(0, 1000)
    ax.invert_yaxis()
    ax.set_xlabel(r'Oxygen ($\mu\text{mol/kg}$)', fontsize=12)
    ax.set_ylabel('Pressure (dbar)', fontsize=12)
    ax.set_title(f'WMO {str(WMOID)} Oxygen Profiles', fontsize=14)


     #add colorbar for top row --------------------------------------------------------------
    sm = cm.ScalarMappable(norm=norm, cmap=cmap)
    sm.set_array([])
    cbar = fig.colorbar(sm, ax=ax, orientation='vertical', label='Date')
    
    tick_locs = np.linspace(date_nums.min(), date_nums.max(), 10)
    cbar.set_ticks(tick_locs)
    cbar.ax.yaxis.set_major_formatter(mdates.DateFormatter('%m-%d-%y'))

    # BBP profile ----------------------------------------------------------------------------
    ax = fig.add_subplot(223)
    for cycle, group in df.groupby('CYCLE_NUMBER'):
        date_val = mdates.date2num(group['DATE'].iloc[0])
        color = cmap(norm(date_val))
        ax.plot(group['BBP700_ADJUSTED'], group['PRES_ADJUSTED'], color=color, lw=2)

    # ax.set_ylim(0, 1000)
    ax.invert_yaxis()
    ax.set_xlabel(r'$b_{bp}$ [$m^{-1}$]', fontsize=12)
    ax.set_ylabel('Pressure (dbar)', fontsize=12)
    ax.set_title(f'WMO {str(WMOID)} Backscatter Profiles', fontsize=14)

    # Nitrate profile ---------------------------------------------------------------------
    ax = fig.add_subplot(224)
    for cycle, group in df.groupby('CYCLE_NUMBER'):
        date_val = mdates.date2num(group['DATE'].iloc[0])
        color = cmap(norm(date_val))
        ax.plot(group['NITRATE_ADJUSTED'], group['PRES_ADJUSTED'], color=color, lw=2)

    # ax.set_ylim(0, 1000)
    ax.invert_yaxis()
    ax.set_xlabel(r'Nitrate ($\mu\text{mol/kg}$', fontsize=12)
    ax.set_ylabel('Pressure (dbar)', fontsize=12)
    ax.set_title(f'WMO {str(WMOID)} Nitrate Profiles', fontsize=14)
    
    #add colorbar for bottom row ----------------------------------------------------------
    sm = cm.ScalarMappable(norm=norm, cmap=cmap)
    sm.set_array([])
    cbar = fig.colorbar(sm, ax=ax, orientation='vertical', label='Date')
    
    tick_locs = np.linspace(date_nums.min(), date_nums.max(), 10)
    cbar.set_ticks(tick_locs)
    cbar.ax.yaxis.set_major_formatter(mdates.DateFormatter('%m-%d-%y'))

    plt.show()

    #save profile
    fig.savefig(f'/Users/lilah/Documents/IBIS_Project/Figures/float_trajectories_depth{season}.png') #uncomment for lilah
    # fig.savefig(f'/Users/steviewalker/Documents/IBIS_Project/Figures/chla_profile_timeseries_WMO{WMOID}_{season}.png') #uncomment for stevie

prof_yr(df = pdf_clean, season = '2014.0-2015.0',WMOID = 5904104)

# %%
# cleaned up depth profiles for 5904104 2014-2015

def profile_clean(df, WMOID, cycle1, cycle2, cycle3):
    
    # df = df[df['season'].isin([season])]
    df = df[df['WMOID'].isin([WMOID])]
    df = df[df['CYCLE_NUMBER'].isin([cycle1, cycle2, cycle3])]
    # df = df[df['CYCLE_NUMBER'].isin([cycle2])]
    # df = df[df['CYCLE_NUMBER'].isin([cycle3])]
    
    df['DATE'] = pd.to_datetime(df['DATE'])
    date_nums = mdates.date2num(df['DATE'])

    fig = plt.figure(figsize=(9,12), layout='constrained')
    
    # CHLA plot -------------------------------------------------------------------
    ax = fig.add_subplot(221)
    ax.plot(df.loc[df['CYCLE_NUMBER'] == 99, 'CHLA_ADJUSTED'], df.loc[df['CYCLE_NUMBER'] == 99, 'PRES_ADJUSTED'], c='darkgreen', ls='-.', alpha=0.7)
    ax.plot(df.loc[df['CYCLE_NUMBER'] == 113, 'CHLA_ADJUSTED'], df.loc[df['CYCLE_NUMBER'] == 113, 'PRES_ADJUSTED'], c='mediumseagreen', ls='--', alpha=0.7)
    ax.plot(df.loc[df['CYCLE_NUMBER'] == 127, 'CHLA_ADJUSTED'], df.loc[df['CYCLE_NUMBER'] == 127, 'PRES_ADJUSTED'], c='yellowgreen', alpha=0.7)
    # ax.set_ylim(0, 200)
    ax.invert_yaxis()
    ax.set_xlabel('Chl-a (mg m$^{-3}$)', fontsize=12)
    ax.set_ylabel('Pressure (dbar)', fontsize=12)
    
    # DOXY plot -------------------------------------------------------------------
    ax = fig.add_subplot(222)
    ax.plot(df.loc[df['CYCLE_NUMBER'] == 99, 'DOXY_ADJUSTED'], df.loc[df['CYCLE_NUMBER'] == 99, 'PRES_ADJUSTED'], c='darkgreen', ls='-.', alpha=0.7)
    ax.plot(df.loc[df['CYCLE_NUMBER'] == 113, 'DOXY_ADJUSTED'], df.loc[df['CYCLE_NUMBER'] == 113, 'PRES_ADJUSTED'], c='purple', ls='--', alpha=0.7)
    ax.plot(df.loc[df['CYCLE_NUMBER'] == 127, 'DOXY_ADJUSTED'], df.loc[df['CYCLE_NUMBER'] == 127, 'PRES_ADJUSTED'], c='blue', alpha=0.7)
    ax.invert_yaxis()
    ax.set_xlabel(r'Oxygen ($\mu\text{mol/kg}$)', fontsize=12)
    ax.set_ylabel('Pressure (dbar)', fontsize=12)
    
    # add colorbar for top row --------------------------------------------------------------
    # sm = cm.ScalarMappable(norm=norm, cmap=cmap)
    # sm.set_array([])
    # cbar = fig.colorbar(sm, ax=ax, orientation='vertical', label='Date')
        
    # tick_locs = np.linspace(date_nums.min(), date_nums.max(), 10)
    # cbar.set_ticks(tick_locs)
    # cbar.ax.yaxis.set_major_formatter(mdates.DateFormatter('%m-%d-%y'))
    
    # BBP700 plot -----------------------------------------------------------------
    ax = fig.add_subplot(223)
    ax.plot(df.loc[df['CYCLE_NUMBER'] == 99, 'BBP700_ADJUSTED'], df.loc[df['CYCLE_NUMBER'] == 99, 'PRES_ADJUSTED'], c='darkgreen', ls='-.', alpha=0.7)
    ax.plot(df.loc[df['CYCLE_NUMBER'] == 113, 'BBP700_ADJUSTED'], df.loc[df['CYCLE_NUMBER'] == 113, 'PRES_ADJUSTED'], c='purple', ls='--', alpha=0.7)
    ax.plot(df.loc[df['CYCLE_NUMBER'] == 127, 'BBP700_ADJUSTED'], df.loc[df['CYCLE_NUMBER'] == 127, 'PRES_ADJUSTED'], c='blue')
    ax.invert_yaxis()
    ax.set_xlabel(r'$b_{bp}$ [$m^{-1}$]', fontsize=12)
    ax.set_ylabel('Pressure (dbar)', fontsize=12)
    
    # NITRATE plot ----------------------------------------------------------------
    ax = fig.add_subplot(224)
    ax.plot(df.loc[df['CYCLE_NUMBER'] == 99, 'NITRATE_ADJUSTED'], df.loc[df['CYCLE_NUMBER'] == 99, 'PRES_ADJUSTED'], c='darkgreen', ls='-.', alpha=0.7)
    ax.plot(df.loc[df['CYCLE_NUMBER'] == 113, 'NITRATE_ADJUSTED'], df.loc[df['CYCLE_NUMBER'] == 113, 'PRES_ADJUSTED'], c='purple', ls='--', alpha=0.7)
    ax.plot(df.loc[df['CYCLE_NUMBER'] == 127, 'NITRATE_ADJUSTED'], df.loc[df['CYCLE_NUMBER'] == 127, 'PRES_ADJUSTED'], c='blue', alpha=0.7)
    ax.invert_yaxis()
    ax.set_xlabel(r'Nitrate ($\mu\text{mol/kg}$', fontsize=12)
    ax.set_ylabel('Pressure (dbar)', fontsize=12)
    
    # add colorbar for bottom row ----------------------------------------------------------
    # sm = cm.ScalarMappable(norm=norm, cmap=cmap)
    # sm.set_array([])
    # cbar = fig.colorbar(sm, ax=ax, orientation='vertical', label='Date')
        
    # tick_locs = np.linspace(date_nums.min(), date_nums.max(), 10)
    # cbar.set_ticks(tick_locs)
    # cbar.ax.yaxis.set_major_formatter(mdates.DateFormatter('%m-%d-%y'))

    plt.show()


profile_clean(df=pdf_clean, WMOID=5904104, cycle1=99, cycle2=113, cycle3=127)

# %%
# cleaned up depth profiles for 5904104 2014-2015

def profile_clean(df, season, WMOID, cycle1, cycle2, cycle3):
    
    df = df[df['season'].isin([season])]
    df = df[df['WMOID'].isin([WMOID])]
    df = df[df['CYCLE_NUMBER'].isin([cycle1, cycle2, cycle3])]
    # df = df[df['CYCLE_NUMBER'].isin([cycle2])]
    # df = df[df['CYCLE_NUMBER'].isin([cycle3])]
    
    df['DATE'] = pd.to_datetime(df['DATE'])
    date_nums = mdates.date2num(df['DATE'])

    fig = plt.figure(figsize=(15,25), layout='constrained')
    
    # CHLA plot -------------------------------------------------------------------
    ax = fig.add_subplot(221)
    ax.plot(df.loc[df['CYCLE_NUMBER'] == 99, 'CHLA_ADJUSTED'], df.loc[df['CYCLE_NUMBER'] == 99, 'PRES_ADJUSTED'], c='#8606a6', lw=4, label='08/10/14')
    ax.plot(df.loc[df['CYCLE_NUMBER'] == 113, 'CHLA_ADJUSTED'], df.loc[df['CYCLE_NUMBER'] == 113, 'PRES_ADJUSTED'], c='#e76e5b', lw=4, label='01/16/15')
    ax.plot(df.loc[df['CYCLE_NUMBER'] == 127, 'CHLA_ADJUSTED'], df.loc[df['CYCLE_NUMBER'] == 127, 'PRES_ADJUSTED'], c='#fdca26', lw=4, label='04/27/15')                
    ax.invert_yaxis()
    ax.set_ylim(500)
    ax.set_xlabel('Chl-a (mg m$^{-3}$)', fontsize=24)
    ax.set_ylabel('Pressure (dbar)', fontsize=24)
    ax.set_title('Chlorophyll a', fontsize=40)
    # Mixed layer pressure lines -----------
    plt.axhline(y=92.670006, color='#8606a6', linestyle='--', lw=2, label='MLP 08/10/14')
    plt.axhline(y=27.43, color='#e76e5b', linestyle='--', lw=2, label='MLP 01/16/15')
    plt.axhline(y=112.35, color='#fdca26', linestyle='--', lw=2, label='MLP 04/27/15')
    ax.legend(fontsize=24)

    # DOXY plot -------------------------------------------------------------------
    ax = fig.add_subplot(222)
    ax.plot(df.loc[df['CYCLE_NUMBER'] == 99, 'DOXY_ADJUSTED'], df.loc[df['CYCLE_NUMBER'] == 99, 'PRES_ADJUSTED'], c='#8606a6', lw=4, label='10/08/14')
    ax.plot(df.loc[df['CYCLE_NUMBER'] == 113, 'DOXY_ADJUSTED'], df.loc[df['CYCLE_NUMBER'] == 113, 'PRES_ADJUSTED'], c='#e76e5b', lw=4, label='01/16/15')
    ax.plot(df.loc[df['CYCLE_NUMBER'] == 127, 'DOXY_ADJUSTED'], df.loc[df['CYCLE_NUMBER'] == 127, 'PRES_ADJUSTED'], c='#fdca26', lw=4, label='04/27/15')
    ax.invert_yaxis()
    ax.set_ylim(500)
    ax.set_xlabel(r'Oxygen ($\mu\text{mol/kg}$)', fontsize=24)
    ax.set_ylabel('Pressure (dbar)', fontsize=24)
    ax.set_title('Dissolved Oxygen', fontsize=40)
    # Mixed layer pressure lines -----------
    plt.axhline(y=92.670006, color='#8606a6', linestyle='--', lw=2, label='MLP 08/10/14')
    plt.axhline(y=27.43, color='#e76e5b', linestyle='--', lw=2, label='MLP 01/16/15')
    plt.axhline(y=112.35, color='#fdca26', linestyle='--', lw=2, label='MLP 04/27/15')
    
    
    # add colorbar for top row --------------------------------------------------------------
    # sm = cm.ScalarMappable(norm=norm, cmap=cmap)
    # sm.set_array([])
    # cbar = fig.colorbar(sm, ax=ax, orientation='vertical', label='Date')
        
    # tick_locs = np.linspace(date_nums.min(), date_nums.max(), 10)
    # cbar.set_ticks(tick_locs)
    # cbar.ax.yaxis.set_major_formatter(mdates.DateFormatter('%m-%d-%y'))
    
    # BBP700 plot -----------------------------------------------------------------
    ax = fig.add_subplot(223)
    ax.plot(df.loc[df['CYCLE_NUMBER'] == 99, 'BBP700_ADJUSTED'], df.loc[df['CYCLE_NUMBER'] == 99, 'PRES_ADJUSTED'], c='#8606a6', lw=4, label='08/10/14')
    ax.plot(df.loc[df['CYCLE_NUMBER'] == 113, 'BBP700_ADJUSTED'], df.loc[df['CYCLE_NUMBER'] == 113, 'PRES_ADJUSTED'], c='#e76e5b', lw=4, label='01/16/15')
    ax.plot(df.loc[df['CYCLE_NUMBER'] == 127, 'BBP700_ADJUSTED'], df.loc[df['CYCLE_NUMBER'] == 127, 'PRES_ADJUSTED'], c='#fdca26', lw=4, label='04/27/15')
    ax.invert_yaxis()
    ax.set_ylim(500)
    ax.set_xlabel(r'$b_{bp}$ [$m^{-1}$]', fontsize=24)
    ax.set_ylabel('Pressure (dbar)', fontsize=24)
    ax.set_title('Backscatter', fontsize=40)
    # Mixed layer pressure lines -----------
    plt.axhline(y=92.670006, color='#8606a6', linestyle='--', lw=2, label='MLP 08/10/14')
    plt.axhline(y=27.43, color='#e76e5b', linestyle='--', lw=2, label='MLP 01/16/15')
    plt.axhline(y=112.35, color='#fdca26', linestyle='--', lw=2, label='MLP 04/27/15')
   

    

    # NITRATE plot ----------------------------------------------------------------
    ax = fig.add_subplot(224)
    ax.plot(df.loc[df['CYCLE_NUMBER'] == 99, 'NITRATE_ADJUSTED'], df.loc[df['CYCLE_NUMBER'] == 99, 'PRES_ADJUSTED'], c='#8606a6', lw=4, label='10/08/14')
    ax.plot(df.loc[df['CYCLE_NUMBER'] == 113, 'NITRATE_ADJUSTED'], df.loc[df['CYCLE_NUMBER'] == 113, 'PRES_ADJUSTED'], c='#e76e5b', lw=4, label='01/16/15')
    ax.plot(df.loc[df['CYCLE_NUMBER'] == 127, 'NITRATE_ADJUSTED'], df.loc[df['CYCLE_NUMBER'] == 127, 'PRES_ADJUSTED'], c='#fdca26', lw=4, label='04/27/15')
    ax.invert_yaxis()
    ax.set_ylim(500)
    ax.set_xlabel(r'Nitrate ($\mu\text{mol/kg}$', fontsize=24)
    ax.set_ylabel('Pressure (dbar)', fontsize=24)
    ax.set_title('Nitrate', fontsize=40)
    # Mixed layer pressure lines -----------
    plt.axhline(y=92.670006, color='#8606a6', linestyle='--', lw=2, label='MLP 08/10/14')
    plt.axhline(y=27.43, color='#e76e5b', linestyle='--', lw=2, label='MLP 01/16/15')
    plt.axhline(y=112.35, color='#fdca26', linestyle='--', lw=2, label='MLP 04/27/15')
 
    
    fig.suptitle('Float 5904104 Depth Profiles', fontsize = 65)
    
    # add colorbar for bottom row ----------------------------------------------------------
    # sm = cm.ScalarMappable(norm=norm, cmap=cmap)
    # sm.set_array([])
    # cbar = fig.colorbar(sm, ax=ax, orientation='vertical', label='Date')
        
    # tick_locs = np.linspace(date_nums.min(), date_nums.max(), 10)
    # cbar.set_ticks(tick_locs)
    # cbar.ax.yaxis.set_major_formatter(mdates.DateFormatter('%m-%d-%y'))

    plt.show()

    # fig.savefig(f'/Users/lilah/Documents/IBIS_Project/Figures/depth_profiles_subset_2014-15.pdf', bbox_inches='tight')

profile_clean(df=pdf_clean, season = '2014.0-2015.0', WMOID=5904104, cycle1=99, cycle2=113, cycle3=127)

# %%
pdf = pd.read_csv('/Users/lilah/Documents/IBIS_Project/Data/AAR_BGC_extended_region_alltime.csv')# cleaned up depth profiles for 5904104 2014-2015

def profile_clean(df, season, WMOID, cycle1, cycle2, cycle3):
    
    df = df[df['season'].isin([season])]
    df = df[df['WMOID'].isin([WMOID])]
    df = df[df['CYCLE_NUMBER'].isin([cycle1, cycle2, cycle3])]
    # df = df[df['CYCLE_NUMBER'].isin([cycle2])]
    # df = df[df['CYCLE_NUMBER'].isin([cycle3])]
    
    df['DATE'] = pd.to_datetime(df['DATE'])
    date_nums = mdates.date2num(df['DATE'])

    fig = plt.figure(figsize=(20, 28), layout='constrained')
    
    # CHLA plot -------------------------------------------------------------------
    ax = fig.add_subplot(231)
    ax.plot(df.loc[df['CYCLE_NUMBER'] == 96, 'CHLA_ADJUSTED'], df.loc[df['CYCLE_NUMBER'] == 96, 'PRES_ADJUSTED'], c='#8606a6', lw=4, label='Before (09/16/14)')
    ax.plot(df.loc[df['CYCLE_NUMBER'] == 113, 'CHLA_ADJUSTED'], df.loc[df['CYCLE_NUMBER'] == 113, 'PRES_ADJUSTED'], c='#e76e5b', lw=4, label='During (01/16/15)')
    ax.plot(df.loc[df['CYCLE_NUMBER'] == 127, 'CHLA_ADJUSTED'], df.loc[df['CYCLE_NUMBER'] == 127, 'PRES_ADJUSTED'], c='#fdca26', lw=4, label='After (04/27/15)')                
    ax.invert_yaxis()
    ax.set_ylim(500, 0)
    ax.set_xlabel('Chl-a (mg m$^{-3}$)', fontsize=40)
    ax.set_ylabel('Pressure (dbar)', fontsize=40)
    ax.tick_params(axis='both', which='major', labelsize=30)
    ax.set_title('A. Chlorophyll-a \nFluorescence', fontsize=50, pad = 15)
    # Mixed layer pressure lines -----------
    plt.axhline(y=92.46, color='#8606a6', linestyle='--', lw=2, label='MLP Before')
    plt.axhline(y=50, color='#e76e5b', linestyle='--', lw=2, label='MLP During')
    plt.axhline(y=112.35, color='#fdca26', linestyle='--', lw=2, label='MLP After')
    ax.legend(fontsize=24)

    # DOXY plot -------------------------------------------------------------------
    ax = fig.add_subplot(232)
    ax.plot(df.loc[df['CYCLE_NUMBER'] == 96, 'DOXY_ADJUSTED'], df.loc[df['CYCLE_NUMBER'] == 96, 'PRES_ADJUSTED'], c='#8606a6', lw=4, label='09/16/14')
    ax.plot(df.loc[df['CYCLE_NUMBER'] == 113, 'DOXY_ADJUSTED'], df.loc[df['CYCLE_NUMBER'] == 113, 'PRES_ADJUSTED'], c='#e76e5b', lw=4, label='01/16/15')
    ax.plot(df.loc[df['CYCLE_NUMBER'] == 127, 'DOXY_ADJUSTED'], df.loc[df['CYCLE_NUMBER'] == 127, 'PRES_ADJUSTED'], c='#fdca26', lw=4, label='04/27/15')
    ax.invert_yaxis()
    ax.set_ylim(500, 0)
    ax.set_xlabel(r'Oxygen ($\mu\text{mol/kg}$)', fontsize=40)
    # ax.set_ylabel('Pressure (dbar)', fontsize=30)
    ax.tick_params(axis='both', which='major', labelsize=30)
    ax.set_title('B. Dissolved \nOxygen', fontsize=50, pad = 15)
    # Mixed layer pressure lines -----------
    plt.axhline(y=92.46, color='#8606a6', linestyle='--', lw=2, label='MLP 09/16/14')
    plt.axhline(y=50, color='#e76e5b', linestyle='--', lw=2, label='MLP 01/16/15')
    plt.axhline(y=112.35, color='#fdca26', linestyle='--', lw=2, label='MLP 04/27/15')
    
    
    # add colorbar for top row --------------------------------------------------------------
    # sm = cm.ScalarMappable(norm=norm, cmap=cmap)
    # sm.set_array([])
    # cbar = fig.colorbar(sm, ax=ax, orientation='vertical', label='Date')
        
    # tick_locs = np.linspace(date_nums.min(), date_nums.max(), 10)
    # cbar.set_ticks(tick_locs)
    # cbar.ax.yaxis.set_major_formatter(mdates.DateFormatter('%m-%d-%y'))
    
    # BBP700 plot -----------------------------------------------------------------
    ax = fig.add_subplot(233)
    ax.plot(df.loc[df['CYCLE_NUMBER'] == 96, 'BBP700_ADJUSTED'], df.loc[df['CYCLE_NUMBER'] == 96, 'PRES_ADJUSTED'], c='#8606a6', lw=4, label='09/16/14')
    ax.plot(df.loc[df['CYCLE_NUMBER'] == 113, 'BBP700_ADJUSTED'], df.loc[df['CYCLE_NUMBER'] == 113, 'PRES_ADJUSTED'], c='#e76e5b', lw=4, label='01/16/15')
    ax.plot(df.loc[df['CYCLE_NUMBER'] == 127, 'BBP700_ADJUSTED'], df.loc[df['CYCLE_NUMBER'] == 127, 'PRES_ADJUSTED'], c='#fdca26', lw=4, label='04/27/15')
    ax.invert_yaxis()
    ax.set_ylim(500, 0)
    ax.set_xlabel(r'$b_{bp}$ ($m^{-1}$)', fontsize=40)
    # ax.set_ylabel('Pressure (dbar)', fontsize=30)
    ax.tick_params(axis='y', which='major', labelsize=30)
    ax.tick_params(axis='x', which='major', labelsize=30, rotation=45)
    ax.set_title('C. Backscatter', fontsize=50, pad = 15)
    # Mixed layer pressure lines -----------
    plt.axhline(y=92.46, color='#8606a6', linestyle='--', lw=2, label='MLP 09/16/14')
    plt.axhline(y=50, color='#e76e5b', linestyle='--', lw=2, label='MLP 01/16/15')
    plt.axhline(y=112.35, color='#fdca26', linestyle='--', lw=2, label='MLP 04/27/15')
   

    

    # NITRATE plot ----------------------------------------------------------------
    ax = fig.add_subplot(234)
    ax.plot(df.loc[df['CYCLE_NUMBER'] == 96, 'NITRATE_ADJUSTED'], df.loc[df['CYCLE_NUMBER'] == 96, 'PRES_ADJUSTED'], c='#8606a6', lw=4, label='09/16/14')
    ax.plot(df.loc[df['CYCLE_NUMBER'] == 113, 'NITRATE_ADJUSTED'], df.loc[df['CYCLE_NUMBER'] == 113, 'PRES_ADJUSTED'], c='#e76e5b', lw=4, label='01/16/15')
    ax.plot(df.loc[df['CYCLE_NUMBER'] == 127, 'NITRATE_ADJUSTED'], df.loc[df['CYCLE_NUMBER'] == 127, 'PRES_ADJUSTED'], c='#fdca26', lw=4, label='04/27/15')
    ax.invert_yaxis()
    ax.set_ylim(500, 0)
    ax.set_xlabel(r'Nitrate ($\mu\text{mol/kg}$)', fontsize=40)
    ax.set_ylabel('Pressure (dbar)', fontsize=40)
    ax.tick_params(axis='both', which='major', labelsize=30)
    ax.set_title('D. Nitrate', fontsize=50, pad = 15)
    # Mixed layer pressure lines -----------
    plt.axhline(y=92.46, color='#8606a6', linestyle='--', lw=2, label='MLP 09/16/14')
    plt.axhline(y=50, color='#e76e5b', linestyle='--', lw=2, label='MLP 01/16/15')
    plt.axhline(y=112.35, color='#fdca26', linestyle='--', lw=2, label='MLP 04/27/15')


    # TEMP PLOT -----------------------------------------------------------------
    ax = fig.add_subplot(235)
    ax.plot(df.loc[df['CYCLE_NUMBER'] == 96, 'CT'], df.loc[df['CYCLE_NUMBER'] == 96, 'PRES_ADJUSTED'], c='#8606a6', lw=4, label='09/16/14')
    ax.plot(df.loc[df['CYCLE_NUMBER'] == 113, 'CT'], df.loc[df['CYCLE_NUMBER'] == 113, 'PRES_ADJUSTED'], c='#e76e5b', lw=4, label='01/16/15')
    ax.plot(df.loc[df['CYCLE_NUMBER'] == 127, 'CT'], df.loc[df['CYCLE_NUMBER'] == 127, 'PRES_ADJUSTED'], c='#fdca26', lw=4, label='04/27/15')
    ax.invert_yaxis()
    ax.set_ylim(500, 0)
    ax.set_xlabel(f'Temperature (\u00B0C)', fontsize=40)
    # ax.set_ylabel('Pressure (dbar)', fontsize=30)
    ax.tick_params(axis='both', which='major', labelsize=30)
    ax.set_title('E. Temperature', fontsize=50, pad = 15)
    # Mixed layer pressure lines -----------
    plt.axhline(y=92.46, color='#8606a6', linestyle='--', lw=2, label='MLP 09/16/14')
    plt.axhline(y=50, color='#e76e5b', linestyle='--', lw=2, label='MLP 01/16/15')
    plt.axhline(y=112.35, color='#fdca26', linestyle='--', lw=2, label='MLP 04/27/15')


    # SALINITY PLOT -----------------------------------------------------------------
    ax = fig.add_subplot(236)
    ax.plot(df.loc[df['CYCLE_NUMBER'] == 96, 'SA'], df.loc[df['CYCLE_NUMBER'] == 96, 'PRES_ADJUSTED'], c='#8606a6', lw=4, label='09/16/14')
    ax.plot(df.loc[df['CYCLE_NUMBER'] == 113, 'SA'], df.loc[df['CYCLE_NUMBER'] == 113, 'PRES_ADJUSTED'], c='#e76e5b', lw=4, label='01/16/15')
    ax.plot(df.loc[df['CYCLE_NUMBER'] == 127, 'SA'], df.loc[df['CYCLE_NUMBER'] == 127, 'PRES_ADJUSTED'], c='#fdca26', lw=4, label='04/27/15')
    ax.invert_yaxis()
    ax.set_ylim(500, 0)
    ax.set_xlabel('Salinity', fontsize=40)
    # ax.set_ylabel('Pressure (dbar)', fontsize=30)
    ax.tick_params(axis='both', which='major', labelsize=30)
    ax.set_title('F. Salinity', fontsize=50, pad = 15)
    # Mixed layer pressure lines -----------
    plt.axhline(y=92.46, color='#8606a6', linestyle='--', lw=2, label='MLP 09/16/14')
    plt.axhline(y=50, color='#e76e5b', linestyle='--', lw=2, label='MLP 01/16/15')
    plt.axhline(y=112.35, color='#fdca26', linestyle='--', lw=2, label='MLP 04/27/15')
 
    
    fig.suptitle('Float 5904104 Depth Profiles', fontsize = 70, y=1.05)
    
    # add colorbar for bottom row ----------------------------------------------------------
    # sm = cm.ScalarMappable(norm=norm, cmap=cmap)
    # sm.set_array([])
    # cbar = fig.colorbar(sm, ax=ax, orientation='vertical', label='Date')
        
    # tick_locs = np.linspace(date_nums.min(), date_nums.max(), 10)
    # cbar.set_ticks(tick_locs)
    # cbar.ax.yaxis.set_major_formatter(mdates.DateFormatter('%m-%d-%y'))

    plt.show()

    fig.savefig(f'/Users/lilah/Documents/IBIS_Project/Figures/depth_profiles_subset_2014-15.svg', dpi = 1000, transparent=True, bbox_inches='tight')
    # fig.savefig(f'/Users/lilah/Documents/IBIS_Project/Figures/depth_profiles_subset_2014-15.png', dpi = 1000, transparent=True, bbox_inches='tight')


profile_clean(df=pdf_yr, season = '2014.0-2015.0', WMOID=5904104, cycle1=96, cycle2=113, cycle3=127)
# Out:
# /var/folders/sr/nn_fjjln6s33md98tyfc3rd40000gn/T/ipykernel_26791/1627789582.py:1: DtypeWarning: Columns (6,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   pdf = pd.read_csv('/Users/lilah/Documents/IBIS_Project/Data/AAR_BGC_extended_region_alltime.csv')# cleaned up depth profiles for 5904104 2014-2015

# %%
#convert to datetime
pdf['DATE'] = pd.to_datetime(pdf['DATE'],format = 'mixed')
pdf = pdf.dropna(subset=["DATE"]) #drop any cycles with no date or lat/lon (I found one cycle on a float that was causing these errors)

# %%
# define function for calculating SA, CT, potential dens, in-situ dens
def calc_phys_vars(df):
        
    # Columns needed
    cols = ['PSAL_ADJUSTED','TEMP_ADJUSTED' ,'PRES_ADJUSTED', 'LATITUDE', 'LONGITUDE']
    
    # only do calculation on good qc T and S data - create nan values where not good data
    qc_flags = [1, 2,5, 8]
    mask_qc = df['PSAL_ADJUSTED_QC'].isin(qc_flags) & df['TEMP_ADJUSTED_QC'].isin(qc_flags)
    df['PSAL_ADJUSTED'] = df['PSAL_ADJUSTED'].where(mask_qc)
    df['TEMP_ADJUSTED'] = df['TEMP_ADJUSTED'].where(mask_qc)    
    
    # mask valid (non-null) rows
    mask = df[cols].notnull().all(axis=1)
    
    # initialize outputs as NaN
    SA = np.full(len(df), np.nan)
    CT = np.full(len(df), np.nan)
    rho = np.full(len(df), np.nan)
    sigma0 = np.full(len(df), np.nan)
    
    # extract numeric arrays for valid rows
    SP = df.loc[mask, 'PSAL_ADJUSTED'].astype(float).to_numpy()
    PT = df.loc[mask, 'TEMP_ADJUSTED'].astype(float).to_numpy()
    pres = df.loc[mask, 'PRES_ADJUSTED'].astype(float).to_numpy()
    LAT = df.loc[mask, 'LATITUDE'].astype(float).to_numpy()
    LON = df.loc[mask, 'LONGITUDE'].astype(float).to_numpy()
    
    # calculate variables using gsw
    SA_valid = gsw.SA_from_SP(SP=SP, p=pres, lon=LON, lat=LAT)
    CT_valid = gsw.CT_from_t(SA=SA_valid, t=PT, p=pres)
    rho_valid = gsw.rho(SA=SA_valid, CT=CT_valid, p=pres)
    sigma0_valid = gsw.sigma0(SA=SA_valid, CT=CT_valid)
    
    # store back into full-length arrays
    SA[mask] = SA_valid
    CT[mask] = CT_valid
    rho[mask] = rho_valid
    sigma0[mask] = sigma0_valid
    
    # sdd results to the dataframe
    df = df.copy()
    df['SA'] = SA
    df['CT'] = CT
    df['rho'] = rho
    df['sigma0'] = sigma0
    
    return df

pdf_yr = calc_phys_vars(pdf_yr)

# %%
pdf_yr
# Out:
#         Unnamed: 0    WMOID  CYCLE_NUMBER DIRECTION  \
# 378645      378645  5904104            90         A
# 378648      378648  5904104            90         A
# 378652      378652  5904104            90         A
# 378655      378655  5904104            90         A
# 378659      378659  5904104            90         A
# ...            ...      ...           ...       ...
# 468548      468548  5904105           127         A
# 468574      468574  5904105           127         A
# 468600      468600  5904105           127         A
# 468626      468626  5904105           127         A
# 468642      468642  5904105           127         A
#
#                              DATE  DATE_QC LATITUDE LONGITUDE  POSITION_QC  \
# 378645 2014-08-04 06:26:51.000680        1  -62.053   152.694            8
# 378648 2014-08-04 06:26:51.000680        1  -62.053   152.694            8
# 378652 2014-08-04 06:26:51.000680        1  -62.053   152.694            8
# ...

# %%
pdf_yr['TEMP_ADJUSTED']
# Out:
# 378645   -1.78100
# 378648   -1.79310
# 378652   -1.79170
# 378655   -1.79475
# 378659   -1.78740
#            ...
# 468548    1.11345
# 468574    1.07150
# 468600    1.03325
# 468626    0.99600
# 468642    0.97700
# Name: TEMP_ADJUSTED, Length: 3472, dtype: float64

# %%
pdf_yr['CT']
# Out:
# 378645   -1.777537
# 378648   -1.789721
# 378652   -1.788415
# 378655   -1.791553
# 378659   -1.784291
#             ...
# 468548    1.072297
# 468574    1.027792
# 468600    0.986876
# 468626    0.946976
# 468642    0.925284
# Name: CT, Length: 3472, dtype: float64

# %%
#function for calculating MLD
#0.03 kg/m3 threshold

def calc_mlp_density(df_profile, delta_sigma=0.03):
    #calc MLD for a single profile using density threshold
    df_profile = df_profile.sort_values('PRES_ADJUSTED')

    # get SA, CT, and potential density values
    SA = df_profile['SA']
    CT = df_profile['CT']
    sigma0 = df_profile['sigma0']

    sigma_surface = sigma0.iloc[0]
    d_sigma = sigma0 - sigma_surface

    # find first depth where density difference exceeds threshold
    idx = np.argmax(d_sigma > delta_sigma)
    if d_sigma.iloc[idx] <= delta_sigma:
        return np.nan  # no threshold reached
    return df_profile['PRES_ADJUSTED'].iloc[idx]

mld = (pdf.groupby(['WMOID', 'CYCLE_NUMBER']).apply(calc_mlp_density).reset_index(name='MLP'))
pdf = pdf.merge(mld, on=['WMOID', 'CYCLE_NUMBER'], how='left')
# Out:
# /var/folders/sr/nn_fjjln6s33md98tyfc3rd40000gn/T/ipykernel_26791/4100982497.py:22: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   mld = (pdf.groupby(['WMOID', 'CYCLE_NUMBER']).apply(calc_mlp_density).reset_index(name='MLP'))

# %%
pdf
# Out:
#         Unnamed: 0    WMOID  CYCLE_NUMBER DIRECTION  \
# 0            25648  2903454             7         A
# 1            25651  2903454             7         A
# 2            25655  2903454             7         A
# 3            25658  2903454             7         A
# 4            25662  2903454             7         A
# ...            ...      ...           ...       ...
# 125564     1519016  7902154            16         A
# 125565     1519017  7902154            16         A
# 125566     1519018  7902154            16         A
# 125567     1519019  7902154            16         A
# 125568     1519020  7902154            16         A
#
#                              DATE  DATE_QC   LATITUDE   LONGITUDE  \
# 0      2023-06-03 04:06:08.000438        1 -64.756039  150.092652
# 1      2023-06-03 04:06:08.000438        1 -64.756039  150.092652
# 2      2023-06-03 04:06:08.000438        1 -64.756039  150.092652
# 3      2023-06-03 04:06:08.000438        1 -64.756039  150.092652
# ...

# %%
# Condition 1: July-Dec 2014
cond1 = (pdf['year'] == 2014) & (pdf['month'] >= 7)

# Condition 2: Jan-June 2015
cond2 = (pdf['year'] == 2015) & (pdf['month'] <= 6)

# Combine them with "OR" (|)
subset_df = pdf[cond1 | cond2]
subset_df['month']
# Out:
# 9518     7.0
# 9519     7.0
# 9520     7.0
# 9521     7.0
# 9522     7.0
#         ...
# 19184    6.0
# 19185    6.0
# 19186    6.0
# 19187    6.0
# 19188    6.0
# Name: month, Length: 4734, dtype: float64

# %%
index_label = subset_df[subset_df['MLP'] == 4.87].index.tolist()
print(index_label)
subset_df.loc[383654:384202, 'MLP'] = np.nan
# Out:
# []

# %%
subset_df['MLP'].min()
# Out:
# 17.2

# %%
mlp_values = subset_df[subset_df['CYCLE_NUMBER'] == 96]['MLP']
print(mlp_values.tolist())
# Out:
# [92.46, 92.46, 92.46, 92.46, 92.46, 92.46, 92.46, 92.46, 92.46, 92.46, 92.46, 92.46, 92.46, 92.46, 92.46, 92.46, 92.46, 92.46, 92.46, 92.46, 92.46, 92.46, 92.46, 92.46, 92.46, 92.46, 92.46, 92.46, 92.46, 92.46, 92.46, 92.46, 92.46, 92.46, 92.46, 92.46, 92.46, 92.46, 92.46, 92.46, 92.46, 92.46, 92.46, 92.46, 92.46, 92.46, 92.46, 92.46, 92.46, 92.46, 92.46, 92.46, 92.46, 92.46, 92.46, 92.46, 92.46, 92.46, 92.46, 92.46]

# %%
mlp_values = subset_df[subset_df['CYCLE_NUMBER'] == 113]['MLP']
print(mlp_values.tolist())
# Out:
# [27.43, 27.43, 27.43, 27.43, 27.43, 27.43, 27.43, 27.43, 27.43, 27.43, 27.43, 27.43, 27.43, 27.43, 27.43, 27.43, 27.43, 27.43, 27.43, 27.43, 27.43, 27.43, 27.43, 27.43, 27.43, 27.43, 27.43, 27.43, 27.43, 27.43, 27.43, 27.43, 27.43, 27.43, 27.43, 27.43, 27.43, 27.43, 27.43, 27.43, 27.43, 27.43, 27.43, 27.43, 27.43, 27.43, 27.43, 27.43, 27.43, 27.43, 27.43, 27.43, 27.43, 27.43, 27.43, 27.43, 27.43, 27.09, 27.09, 27.09, 27.09, 27.09, 27.09, 27.09, 27.09, 27.09, 27.09, 27.09, 27.09, 27.09, 27.09, 27.09, 27.09, 27.09, 27.09, 27.09, 27.09, 27.09, 27.09, 27.09, 27.09, 27.09, 27.09, 27.09, 27.09, 27.09, 27.09, 27.09, 27.09, 27.09, 27.09, 27.09, 27.09, 27.09, 27.09, 27.09, 27.09, 27.09, 27.09, 27.09, 27.09, 27.09, 27.09, 27.09, 27.09, 27.09, 27.09, 27.09, 27.09, 27.09, 27.09, 27.09, 27.09, 27.09]

# %%
mlp_values = subset_df[subset_df['CYCLE_NUMBER'] == 127]['MLP']
print(mlp_values.tolist())
# Out:
# [112.35, 112.35, 112.35, 112.35, 112.35, 112.35, 112.35, 112.35, 112.35, 112.35, 112.35, 112.35, 112.35, 112.35, 112.35, 112.35, 112.35, 112.35, 112.35, 112.35, 112.35, 112.35, 112.35, 112.35, 112.35, 112.35, 112.35, 112.35, 112.35, 112.35, 112.35, 112.35, 112.35, 112.35, 112.35, 112.35, 112.35, 112.35, 112.35, 112.35, 112.35, 112.35, 112.35, 112.35, 112.35, 112.35, 112.35, 112.35, 112.35, 112.35, 112.35, 112.35, 112.35, 112.35, 112.35, 112.35, 112.35, 112.35, 112.35, 112.35, 72.600006, 72.600006, 72.600006, 72.600006, 72.600006, 72.600006, 72.600006, 72.600006, 72.600006, 72.600006, 72.600006, 72.600006, 72.600006, 72.600006, 72.600006, 72.600006, 72.600006, 72.600006, 72.600006, 72.600006, 72.600006, 72.600006, 72.600006, 72.600006, 72.600006, 72.600006, 72.600006, 72.600006, 72.600006, 72.600006, 72.600006, 72.600006, 72.600006, 72.600006, 72.600006, 72.600006, 72.600006, 72.600006, 72.600006, 72.600006, 72.600006, 72.600006, 72.600006, 72.600006, 72.600006, 72.600006, 72.600006, 
# ...

# %%
mlp_values = subset_df[subset_df['CYCLE_NUMBER'] == 96]['DATE']
print(mlp_values.tolist())
# Out:
# [Timestamp('2014-09-16 12:12:58.001302'), Timestamp('2014-09-16 12:12:58.001302'), Timestamp('2014-09-16 12:12:58.001302'), Timestamp('2014-09-16 12:12:58.001302'), Timestamp('2014-09-16 12:12:58.001302'), Timestamp('2014-09-16 12:12:58.001302'), Timestamp('2014-09-16 12:12:58.001302'), Timestamp('2014-09-16 12:12:58.001302'), Timestamp('2014-09-16 12:12:58.001302'), Timestamp('2014-09-16 12:12:58.001302'), Timestamp('2014-09-16 12:12:58.001302'), Timestamp('2014-09-16 12:12:58.001302'), Timestamp('2014-09-16 12:12:58.001302'), Timestamp('2014-09-16 12:12:58.001302'), Timestamp('2014-09-16 12:12:58.001302'), Timestamp('2014-09-16 12:12:58.001302'), Timestamp('2014-09-16 12:12:58.001302'), Timestamp('2014-09-16 12:12:58.001302'), Timestamp('2014-09-16 12:12:58.001302'), Timestamp('2014-09-16 12:12:58.001302'), Timestamp('2014-09-16 12:12:58.001302'), Timestamp('2014-09-16 12:12:58.001302'), Timestamp('2014-09-16 12:12:58.001302'), Timestamp('2014-09-16 12:12:58.001302'), Timestamp('20
# ...

# %%
mlp_values = subset_df[subset_df['CYCLE_NUMBER'] == 127]['DATE']
print(mlp_values.tolist())
# Out:
# [Timestamp('2015-04-27 19:55:25.002120'), Timestamp('2015-04-27 19:55:25.002120'), Timestamp('2015-04-27 19:55:25.002120'), Timestamp('2015-04-27 19:55:25.002120'), Timestamp('2015-04-27 19:55:25.002120'), Timestamp('2015-04-27 19:55:25.002120'), Timestamp('2015-04-27 19:55:25.002120'), Timestamp('2015-04-27 19:55:25.002120'), Timestamp('2015-04-27 19:55:25.002120'), Timestamp('2015-04-27 19:55:25.002120'), Timestamp('2015-04-27 19:55:25.002120'), Timestamp('2015-04-27 19:55:25.002120'), Timestamp('2015-04-27 19:55:25.002120'), Timestamp('2015-04-27 19:55:25.002120'), Timestamp('2015-04-27 19:55:25.002120'), Timestamp('2015-04-27 19:55:25.002120'), Timestamp('2015-04-27 19:55:25.002120'), Timestamp('2015-04-27 19:55:25.002120'), Timestamp('2015-04-27 19:55:25.002120'), Timestamp('2015-04-27 19:55:25.002120'), Timestamp('2015-04-27 19:55:25.002120'), Timestamp('2015-04-27 19:55:25.002120'), Timestamp('2015-04-27 19:55:25.002120'), Timestamp('2015-04-27 19:55:25.002120'), Timestamp('20
# ...
